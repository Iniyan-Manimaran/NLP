# %% [markdown]
# # CHUNKING
# Chunking is a process of extracting phrases from unstructured text, which means analyzing a sentence to identify the constituents(Noun Groups, Verbs, verb groups, etc.) It works on top of POS tagging. It uses POS-tags as input and provides chunks as output.

# %%
import nltk
from nltk.corpus import state_union
from nltk.tokenize import PunktSentenceTokenizer

# %%
train_text = state_union.raw("C:/datasets_2119_3569_state_union_1954-Eisenhower.txt")
sample_text = state_union.raw("C:/datasets_2119_3569_state_union_1955-Eisenhower.txt")

# %%
custom_sent_tokenizer = PunktSentenceTokenizer(train_text)

# %%
tokenized = custom_sent_tokenizer.tokenize(sample_text)

# %%
def process_content():
    try:
        for i in tokenized:
            words = nltk.word_tokenize(i)
            tagged = nltk.pos_tag(words)
            chunkGram = r"""Chunk: {<RB.?>*<VB.?>*<NNP>+<NN>?}"""
            chunkParser = nltk.RegexpParser(chunkGram)
            chunked = chunkParser.parse(tagged)
            result=chunkParser.parse(nltk.pos_tag(train_text))
            print(result)
            chunked.draw()     
    except Exception as e:
        print(str(e))

process_content()
# Out:
# (S
#   (Chunk P/NNP R/NNP E/NNP S/NNP)
#   I/PRP
#   (Chunk D/NNP E/NNP N/NNP T/NNP  /NNP D/NNP W/NNP)
#   I/PRP
#   (Chunk G/NNP H/NNP T/NNP  /NNP D/NNP)
#   ./.
#    /CC
#   (Chunk E/NNP)
#   I/PRP
#   (Chunk S/NNP E/NNP N/NNP H/NNP O/NNP W/NNP E/NNP R/NNP)
#   '/POS
#   (Chunk S/NNP)
#   (Chunk
#      /VBZ
#     A/NNP
#     N/NNP
#     N/NNP
#     U/NNP
#     A/NNP
#     L/NNP
#      /NNP
#     M/NNP
#     E/NNP
#     S/NNP
#     S/NNP
#     A/NNP
#     G/NNP
#     E/NNP
#      /NNP
#     T/NNP
#     O/NNP
#      /NNP
#     T/NNP
#     H/NNP
#     E/NNP
#      /NNP
#     C/NNP
#     O/NNP
#     N/NNP
#     G/NNP
#     R/NNP
#     E/NNP
#     S/NNP
#     S/NNP
#      /NNP
#     O/NNP
#     N/NNP
#      /NNP
#     T/NNP
#     H/NNP
#     E/NNP
#      /NNP
#     S/NNP
#     T/NNP
#     A/NNP
#     T/NNP
#     E/NNP
#      /NNP
#     O/NNP
#     F/NNP
#      /NNP
#     T/NNP
#     H/NNP
#     E/NNP
#      /NNP
#     U/NNP
#     N/NNP)
#   I/PRP
#   (Chunk O/NNP N/NNP
# /NNP  /NNP
# /NNP J/NNP)
#   a/DT
#   n/JJ
#   u/NN
#   a/DT
#   r/NN
#   y/NN
#    /VBD
#   7/CD
#   ,/,
#    /VBD
#   1/CD
#   9/CD
#   5/CD
#   4/CD
#
# /NN
#   (Chunk
# /NNP M/NNP r/NN)
#   ./.
#    /CC
#   (Chunk P/NNP)
#   r/VBP
#   e/JJ
#   s/NN
#   i/NN
#   d/VBP
#   e/NN
#   n/JJ
#   t/NN
#   ,/,
#   (Chunk  /NNP M/NNP r/NN)
#   ./.
#    /CC
#   (Chunk S/NNP)
#   p/VBP
#   e/VBZ
#   a/DT
#   k/NN
#   e/NN
#   r/NN
#   ,/,
#   (Chunk  /NNP M/NNP e/NN)
#   m/NN
#   b/NN
#   e/NN
#   r/NN
#   s/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP E/NNP i/NN)
#   g/VBP
#   h/NN
#   t/NN
#   y/SYM
#   -/:
#   t/NN
#   h/NN
#   i/JJ
#   r/VBP
#   d/JJ
#   (Chunk  /NNP C/NNP)
#   o/MD
#   n/VB
#   g/JJ
#   r/NN
#   e/NN
#   s/JJ
#   s/NN
#   :/:
#
# /NN
#   I/PRP
#   t/VBP
#    /JJ
#   i/NN
#   s/VBP
#    /PDT
#   a/DT
#    /JJ
#   h/NN
#   i/NN
#   g/VBP
#   h/NN
#    /NN
#   h/NN
#   o/JJ
#   n/NN
#   o/NN
#   r/NN
#    /VBZ
#   a/DT
#   g/NN
#   a/DT
#   i/NN
#   n/MD
#    /VB
#   t/JJ
#   o/NN
#   (Chunk  /NNP p/NN)
#   r/NN
#   e/NN
#   s/NN
#   e/NN
#   n/JJ
#   t/NN
#   (Chunk  /NNP t/NN)
#   o/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP C/NNP)
#   o/MD
#   n/VB
#   g/JJ
#   r/NN
#   e/NN
#   s/NN
#   s/NN
#   (Chunk  /NNP m/NN)
#   y/NN
#   (Chunk  /NNP v/NN)
#   i/NN
#   e/VBP
#   w/NN
#   s/NN
#   (Chunk  /NNP)
#   o/VBZ
#   n/JJ
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP)
#   s/VBZ
#   t/VB
#   a/DT
#   t/NN
#   e/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP U/NNP n/NN)
#   i/NN
#   o/VBP
#   n/RB
#    /VBP
#   a/DT
#   n/JJ
#   d/NN
#   (Chunk  /NNP t/NN)
#   o/NN
#   (Chunk  /NNP r/NN)
#   e/NN
#   c/VBP
#   o/JJ
#   m/NN
#   m/NN
#   e/NN
#   n/JJ
#   d/NN
#   (Chunk  /NNP m/NN)
#   e/VBZ
#   a/DT
#   s/NN
#   u/JJ
#   r/NN
#   e/NN
#   s/NN
#   (Chunk  /NNP t/NN)
#   o/NN
#    /VBZ
#   a/DT
#   d/NN
#   v/NN
#   a/DT
#   n/JJ
#   c/NN
#   e/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP s/NN)
#   e/NN
#   c/NN
#   u/JJ
#   r/NN
#   i/NN
#   t/VBP
#   y/NN
#   ,/,
#   (Chunk  /NNP)
#   p/VBZ
#   r/NN
#   o/NN
#   s/NN
#   p/NN
#   e/NN
#   r/NN
#   i/NN
#   t/VBP
#   y/NN
#   ,/,
#    /VB
#   a/DT
#   n/JJ
#   d/NN
#   (Chunk  /NNP w/NN)
#   e/NN
#   l/NN
#   l/NN
#   -/:
#   b/NN
#   e/NN
#   i/NN
#   n/VBP
#   g/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /VBZ A/NNP m/NN)
#   e/NN
#   r/NN
#   i/NN
#   c/VBP
#   a/DT
#   n/JJ
#    /NN
#   p/NN
#   e/NN
#   o/IN
#   p/NN
#   l/NN
#   e/NN
#   ./.
#
# /VB
#   A/DT
#   l/NN
#   l/NN
#    /NN
#   b/NN
#   r/NN
#   a/DT
#   n/JJ
#   c/NN
#   h/NN
#   e/NN
#   s/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP t/NN)
#   h/NN
#   i/JJ
#   s/VBP
#    /JJ
#   (Chunk G/NNP o/NN)
#   v/NN
#   e/NN
#   r/NN
#   n/JJ
#   m/NN
#   e/NN
#   n/FW
#   t/SYM
#   -/:
#   -/:
#   a/DT
#   n/JJ
#   d/NN
#    /NN
#   I/PRP
#    /VBP
#   v/JJ
#   e/NN
#   n/JJ
#   t/NN
#   u/JJ
#   r/NN
#   e/NN
#   (Chunk  /NNP t/NN)
#   o/NN
#   (Chunk  /NNP)
#   s/VBZ
#   a/DT
#   y/NN
#    /NN
#   b/NN
#   o/NN
#   t/NN
#   h/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP o/NN)
#   u/JJ
#   r/NN
#   (Chunk  /NNP g/NN)
#   r/NN
#   e/VBZ
#   a/DT
#   t/NN
#   (Chunk  /NNP)
#   p/VBZ
#   a/DT
#   r/NN
#   t/NN
#   i/NN
#   e/VBP
#   s/SYM
#   -/:
#   -/:
#   c/VB
#   a/DT
#   n/JJ
#    /NN
#   s/NN
#   u/JJ
#   p/NN
#   p/NN
#   o/NN
#   r/NN
#   t/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP g/NN)
#   e/NN
#   n/JJ
#   e/NN
#   r/VBZ
#   a/DT
#   l/NN
#   (Chunk  /NNP o/NN)
#   b/NN
#   j/NN
#   e/NN
#   c/VBP
#   t/NN
#   i/NN
#   v/VBP
#   e/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP r/NN)
#   e/NN
#   c/VBP
#   o/JJ
#   m/NN
#   m/NN
#   e/NN
#   n/JJ
#   d/VBZ
#   a/DT
#   t/NN
#   i/NN
#   o/VBP
#   n/JJ
#   s/NN
#   (Chunk  /NNP)
#   (/(
#   (Chunk P/NNP g/NN)
#   ./.
#    /VB
#   7/CD
#   )/)
#    /NN
#   I/PRP
#    /VBP
#   m/VB
#   a/DT
#   k/NN
#   e/NN
#   (Chunk  /NNP t/NN)
#   o/NN
#   d/VBZ
#   a/DT
#   y/NN
#   ,/,
#   (Chunk  /NNP)
#   f/VBZ
#   o/JJ
#   r/NN
#   (Chunk  /NNP t/NN)
#   h/VBD
#   a/DT
#   t/NN
#   (Chunk  /NNP o/NN)
#   b/NN
#   j/NN
#   e/NN
#   c/VBP
#   t/NN
#   i/NN
#   v/VBP
#   e/NN
#    /NN
#   i/NN
#   s/VBP
#    /JJ
#   t/NN
#   h/NN
#   e/NN
#   (Chunk  /NNP b/NN)
#   u/NN
#   i/NN
#   l/VBP
#   d/NN
#   i/NN
#   n/VBP
#   g/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#    /IN
#   a/DT
#    /JJ
#   s/NN
#   t/NN
#   r/NN
#   o/NN
#   n/JJ
#   g/NN
#   e/NN
#   r/NN
#   (Chunk  /VBZ A/NNP m/NN)
#   e/NN
#   r/NN
#   i/NN
#   c/VBP
#   a/DT
#   ./.
#    /VB
#   A/DT
#    /JJ
#   n/NN
#   a/DT
#   t/NN
#   i/NN
#   o/VBP
#   n/JJ
#   (Chunk  /NNP w/NN)
#   h/NN
#   o/JJ
#   s/NN
#   e/NN
#   (Chunk  /NNP e/NN)
#   v/NN
#   e/NN
#   r/NN
#   y/NN
#   (Chunk  /NNP c/NN)
#   i/NN
#   t/VBP
#   i/JJ
#   z/VBP
#   e/JJ
#   n/JJ
#    /NN
#   h/VBD
#   a/DT
#   s/JJ
#    /NN
#   g/NN
#   o/NN
#   o/NN
#   d/NN
#   (Chunk  /NNP r/NN)
#   e/VBZ
#   a/DT
#   s/JJ
#   o/NN
#   n/JJ
#   (Chunk  /NNP f/NN)
#   o/NN
#   r/NN
#    /NN
#   b/NN
#   o/NN
#   l/NN
#   d/NN
#   (Chunk  /NNP h/NN)
#   o/NN
#   p/NN
#   e/NN
#   ;/:
#    /CC
#   w/VB
#   h/NN
#   e/NN
#   r/NN
#   e/NN
#   (Chunk  /NNP e/NN)
#   f/NN
#   f/NN
#   o/NN
#   r/NN
#   t/IN
#    /NN
#   i/NN
#   s/VBP
#    /JJ
#   r/NN
#   e/NN
#   w/VBD
#   a/DT
#   r/NN
#   d/NN
#   e/NN
#   d/NN
#    /VBZ
#   a/DT
#   n/JJ
#   d/NN
#   (Chunk  /NNP p/NN)
#   r/NN
#   o/NN
#   s/NN
#   p/NN
#   e/NN
#   r/NN
#   i/NN
#   t/VBP
#   y/NN
#    /NN
#   i/NN
#   s/VBP
#    /JJ
#   s/NN
#   h/VBD
#   a/DT
#   r/NN
#   e/NN
#   d/NN
#   ;/:
#    /CC
#   w/VB
#   h/NN
#   e/NN
#   r/NN
#   e/NN
#   (Chunk  /NNP f/NN)
#   r/NN
#   e/NN
#   e/NN
#   d/NN
#   o/IN
#   m/JJ
#   (Chunk  /NNP e/NN)
#   (Chunk x/NNP)
#   p/VBZ
#   a/DT
#   n/JJ
#   d/NN
#   s/NN
#    /VBZ
#   a/DT
#   n/JJ
#   d/NN
#   (Chunk  /NNP p/NN)
#   e/VBZ
#   a/DT
#   c/JJ
#   e/NN
#    /NN
#   i/NN
#   s/VBP
#    /JJ
#   s/NN
#   e/NN
#   c/NN
#   u/JJ
#   r/NN
#   e/SYM
#   -/:
#   -/:
#   t/NN
#   h/VBZ
#   a/DT
#   t/JJ
#    /NN
#   i/NN
#   s/VBP
#    /JJ
#   w/NN
#   h/VBD
#   a/DT
#   t/NN
#    /NN
#   I/PRP
#    /VBP
#   m/JJ
#   e/NN
#   a/DT
#   n/JJ
#    /NN
#   b/NN
#   y/NN
#    /VBZ
#   a/DT
#    /JJ
#   s/NN
#   t/NN
#   r/NN
#   o/NN
#   n/JJ
#   g/NN
#   e/NN
#   r/NN
#   (Chunk  /VBZ A/NNP m/NN)
#   e/NN
#   r/NN
#   i/NN
#   c/VBP
#   a/DT
#   ./.
#
# /JJ
#   (Chunk T/NNP o/NN)
#   w/VBD
#   a/DT
#   r/NN
#   d/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   i/JJ
#   s/VBP
#    /JJ
#   o/NN
#   b/NN
#   j/NN
#   e/NN
#   c/VBP
#   t/NN
#   i/NN
#   v/VBP
#   e/NN
#    /VBP
#   a/DT
#    /JJ
#   r/NN
#   e/VBZ
#   a/DT
#   l/NN
#   (Chunk  /NNP m/NN)
#   o/NN
#   m/NN
#   e/NN
#   n/JJ
#   t/NN
#   u/JJ
#   m/NN
#   (Chunk  /NNP)
#   h/VBZ
#   a/DT
#   s/NN
#    /NN
#   b/NN
#   e/NN
#   e/NN
#   n/JJ
#   (Chunk  /NNP d/NN)
#   e/NN
#   v/NN
#   e/NN
#   l/NN
#   o/NN
#   p/NN
#   e/NN
#   d/NN
#   (Chunk  /NNP d/NN)
#   u/JJ
#   r/NN
#   i/NN
#   n/VBP
#   g/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   i/JJ
#   s/VBP
#    /PDT
#   (Chunk A/NNP d/NN)
#   m/NN
#   i/NN
#   n/VBP
#   i/NN
#   s/VBP
#   t/NN
#   r/NN
#   a/DT
#   t/NN
#   i/NN
#   o/VBP
#   n/NN
#   '/''
#   s/JJ
#   (Chunk  /NNP f/NN)
#   i/NN
#   r/VBP
#   s/NN
#   t/NN
#   (Chunk  /NNP y/NNP)
#   e/VBZ
#   a/DT
#   r/NN
#    /NN
#   i/NN
#   n/VBP
#    /JJ
#   o/NN
#   f/NN
#   f/NN
#   i/NN
#   c/VBP
#   e/NN
#   ./.
#    /CC
#   (Chunk W/NNP)
#   (Chunk e/VBP  /NNP m/NN)
#   e/VBZ
#   a/DT
#   n/JJ
#    /NN
#   t/NN
#   o/NN
#   (Chunk  /NNP)
#   c/VBZ
#   o/JJ
#   n/IN
#   t/NN
#   i/NN
#   n/VBP
#   u/JJ
#   e/NN
#   (Chunk  /NNP t/NN)
#   h/VBD
#   a/DT
#   t/NN
#   (Chunk  /NNP m/NN)
#   o/NN
#   m/NN
#   e/NN
#   n/JJ
#   t/NN
#   u/JJ
#   m/NN
#    /VBD
#   a/DT
#   n/JJ
#   d/NN
#   (Chunk  /NNP t/NN)
#   o/NN
#    /NN
#   i/NN
#   n/VBP
#   c/NN
#   r/NN
#   e/VBZ
#   a/DT
#   s/JJ
#   e/NN
#    /NN
#   i/NN
#   t/NN
#   ./.
#    /CC
#   (Chunk W/NNP)
#   (Chunk e/VBP  /NNP m/NN)
#   e/VBZ
#   a/DT
#   n/JJ
#    /NN
#   t/NN
#   o/NN
#    /NN
#   b/IN
#   u/JJ
#   i/NN
#   l/VBP
#   d/NN
#    /VBP
#   a/DT
#    /NN
#   b/NN
#   e/NN
#   t/NN
#   t/NN
#   e/NN
#   r/NN
#   (Chunk  /NNP f/NN)
#   u/JJ
#   t/NN
#   u/JJ
#   r/NN
#   e/NN
#   (Chunk  /NNP f/NN)
#   o/NN
#   r/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   i/JJ
#   s/VBP
#    /JJ
#   n/IN
#   a/DT
#   t/NN
#   i/NN
#   o/VBP
#   n/NN
#   ./.
#
# /CC
#   (Chunk M/NNP)
#   u/JJ
#   c/NN
#   h/NN
#   (Chunk  /NNP f/NN)
#   o/NN
#   r/NN
#   (Chunk  /NNP w/NN)
#   h/NN
#   i/JJ
#   c/VBP
#   h/JJ
#   (Chunk  /NNP w/NN)
#   e/NN
#   (Chunk  /NNP)
#   m/VBZ
#   a/DT
#   y/NN
#    /NN
#   b/NN
#   e/NN
#   (Chunk  /NNP t/NN)
#   h/VBD
#   a/DT
#   n/JJ
#   k/NN
#   f/NN
#   u/JJ
#   l/NN
#   (Chunk  /NNP)
#   h/VBZ
#   a/DT
#   s/JJ
#    /NN
#   h/VBD
#   a/DT
#   p/NN
#   p/NN
#   e/NN
#   n/JJ
#   e/NN
#   d/NN
#   (Chunk  /NNP d/NN)
#   u/JJ
#   r/NN
#   i/NN
#   n/VBP
#   g/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP)
#   p/VBZ
#   a/DT
#   s/JJ
#   t/NN
#   (Chunk  /NNP y/NNP)
#   e/VBZ
#   a/DT
#   r/NN
#   ./.
#
# /JJ
#   (Chunk F/NNP i/NN)
#   r/VBP
#   s/NN
#   t/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#    /IN
#   a/DT
#   l/NN
#   l/NN
#   (Chunk  /NNP w/NN)
#   e/NN
#    /VBZ
#   a/DT
#   r/NN
#   e/NN
#   (Chunk  /NNP d/NN)
#   e/NN
#   e/NN
#   p/NN
#   l/NN
#   y/NN
#   (Chunk  /NNP g/NN)
#   r/NN
#   a/DT
#   t/NN
#   e/NN
#   f/NN
#   u/JJ
#   l/NN
#   (Chunk  /NNP t/NN)
#   h/VBD
#   a/DT
#   t/NN
#   (Chunk  /NNP o/NN)
#   u/JJ
#   r/NN
#   (Chunk  /NNP s/NN)
#   o/NN
#   n/JJ
#   s/NN
#   (Chunk  /NNP)
#   n/CC
#   o/JJ
#   (Chunk  /NNP l/NN)
#   o/NN
#   n/JJ
#   g/NN
#   e/NN
#   r/NN
#   (Chunk  /NNP d/NN)
#   i/NN
#   e/VBP
#    /JJ
#   o/NN
#   n/JJ
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP d/NN)
#   i/NN
#   s/VBP
#   t/IN
#   a/DT
#   n/JJ
#   t/NN
#   (Chunk  /NNP m/NN)
#   o/NN
#   u/JJ
#   n/JJ
#   t/IN
#   a/DT
#   i/JJ
#   n/NN
#   s/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP K/NNP o/NNP r/NN)
#   e/VBD
#   a/DT
#   ./.
#    /VB
#   A/DT
#   l/NN
#   t/NN
#   h/NN
#   o/JJ
#   u/JJ
#   g/NN
#   h/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   y/NN
#    /VBZ
#   a/DT
#   r/NN
#   e/NN
#   (Chunk  /NNP s/NN)
#   t/NN
#   i/NN
#   l/VBP
#   l/NN
#   (Chunk  /NNP)
#   c/VBZ
#   a/DT
#   l/NN
#   l/NN
#   e/NN
#   d/NN
#   (Chunk  /NNP f/NN)
#   r/NN
#   o/IN
#   m/NN
#   (Chunk  /NNP o/NN)
#   u/JJ
#   r/NN
#   (Chunk  /NNP h/NN)
#   o/NN
#   m/NN
#   e/NN
#   s/NN
#   (Chunk  /NNP t/NN)
#   o/NN
#   (Chunk  /NNP m/NN)
#   i/NN
#   l/VBP
#   i/NN
#   t/VBP
#   a/DT
#   r/NN
#   y/NN
#   (Chunk  /NNP s/NN)
#   e/NN
#   r/NN
#   v/NN
#   i/NN
#   c/VBP
#   e/NN
#   ,/,
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   y/NN
#    /VBZ
#   a/DT
#   r/NN
#   e/NN
#   (Chunk  /NNP)
#   n/CC
#   o/JJ
#   (Chunk  /NNP l/NN)
#   o/NN
#   n/JJ
#   g/NN
#   e/NN
#   r/NN
#   (Chunk  /NNP)
#   c/VBZ
#   a/DT
#   l/NN
#   l/NN
#   e/NN
#   d/NN
#   (Chunk  /NNP t/NN)
#   o/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP f/NN)
#   i/NN
#   e/VBP
#   l/NN
#   d/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP b/NN)
#   a/DT
#   t/NN
#   t/NN
#   l/NN
#   e/NN
#   ./.
#
# /CC
#   (Chunk T/NNP)
#   h/VBP
#   e/JJ
#   (Chunk  /NNP)
#   n/FW
#   a/DT
#   t/NN
#   i/NN
#   o/VBP
#   n/JJ
#   (Chunk  /NNP h/NN)
#   a/DT
#   s/JJ
#   (Chunk  /NNP j/NN)
#   u/JJ
#   s/NN
#   t/NN
#   (Chunk  /NNP)
#   c/VBZ
#   o/JJ
#   m/NN
#   p/NN
#   l/NN
#   e/NN
#   t/NN
#   e/NN
#   d/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP m/NN)
#   o/NN
#   s/NN
#   t/NN
#   (Chunk  /NNP p/NN)
#   r/NN
#   o/NN
#   s/NN
#   p/NN
#   e/NN
#   r/NN
#   o/NN
#   u/JJ
#   s/NN
#   (Chunk  /NNP y/NNP)
#   e/VBZ
#   a/DT
#   r/NN
#    /NN
#   i/NN
#   n/VBP
#    /NN
#   i/NN
#   t/VBP
#   s/NN
#    /NN
#   h/NN
#   i/JJ
#   s/VBP
#   t/JJ
#   o/NN
#   r/NN
#   y/NN
#   ./.
#    /CC
#   (Chunk T/NNP)
#   h/VBP
#   e/JJ
#   (Chunk  /NNP d/NN)
#   a/DT
#   m/NN
#   a/DT
#   g/NN
#   i/NN
#   n/VBP
#   g/NN
#   (Chunk  /NNP e/NN)
#   f/NN
#   f/NN
#   e/NN
#   c/VBP
#   t/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#    /NN
#   i/NN
#   n/VBP
#   f/NN
#   l/NN
#   a/DT
#   t/NN
#   i/NN
#   o/VBP
#   n/JJ
#   (Chunk  /NNP o/NN)
#   n/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP)
#   w/VBZ
#   a/DT
#   g/NN
#   e/NN
#   s/NN
#   ,/,
#   (Chunk  /NNP)
#   p/VBZ
#   e/FW
#   n/JJ
#   s/NN
#   i/NN
#   o/VBP
#   n/JJ
#   s/NN
#   ,/,
#   (Chunk  /NNP)
#   s/VBD
#   a/DT
#   l/NN
#   a/DT
#   r/NN
#   i/NN
#   e/VBP
#   s/JJ
#    /FW
#   a/DT
#   n/JJ
#   d/NN
#   (Chunk  /NNP)
#   s/VBZ
#   a/DT
#   v/NN
#   i/NN
#   n/VBP
#   g/NN
#   s/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP u/NN)
#   s/NN
#    /VBZ
#   a/DT
#   l/NN
#   l/NN
#   (Chunk  /NNP)
#   h/VBZ
#   a/DT
#   s/NN
#    /NN
#   b/NN
#   e/NN
#   e/NN
#   n/JJ
#    /NN
#   b/NN
#   r/NN
#   o/NN
#   u/JJ
#   g/NN
#   h/NN
#   t/NN
#   (Chunk  /NNP)
#   u/JJ
#   n/RB
#   d/VBP
#   e/JJ
#   r/NN
#   (Chunk  /NNP)
#   c/VBZ
#   o/JJ
#   n/JJ
#   t/NN
#   r/NN
#   o/NN
#   l/NN
#   ./.
#   (Chunk  /VB T/NNP)
#   a/DT
#   (Chunk x/NNP e/NN)
#   s/NN
#   (Chunk  /NNP)
#   h/VBZ
#   a/DT
#   v/NN
#   e/NN
#   (Chunk  /NNP b/NN)
#   e/NN
#   g/NN
#   u/JJ
#   n/JJ
#    /NN
#   t/NN
#   o/NN
#   (Chunk  /NNP g/NN)
#   o/NN
#   (Chunk  /NNP d/NN)
#   o/NN
#   w/NN
#   n/NN
#   ./.
#    /CC
#   (Chunk T/NNP)
#   h/VBP
#   e/JJ
#   (Chunk  /NNP c/NN)
#   o/NN
#   s/NN
#   t/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP o/NN)
#   u/JJ
#   r/NN
#   (Chunk  /NNP g/NN)
#   o/NN
#   v/NN
#   e/NN
#   r/NN
#   n/JJ
#   m/NN
#   e/NN
#   n/JJ
#   t/NN
#   (Chunk  /NNP)
#   h/VBZ
#   a/DT
#   s/NN
#    /NN
#   b/NN
#   e/NN
#   e/NN
#   n/JJ
#   (Chunk  /NNP r/NN)
#   e/NN
#   d/NN
#   u/JJ
#   c/NN
#   e/NN
#   d/NN
#    /VBZ
#   a/DT
#   n/JJ
#   d/NN
#    /NN
#   i/NN
#   t/VBP
#   s/NN
#   (Chunk  /NNP w/NN)
#   o/NN
#   r/NN
#   k/NN
#   (Chunk  /NNP p/NN)
#   r/NN
#   o/IN
#   c/JJ
#   e/NN
#   e/NN
#   d/NN
#   s/NN
#   (Chunk  /NNP w/NN)
#   i/NN
#   t/VBP
#   h/NN
#   (Chunk  /NNP s/NN)
#   o/NN
#   m/NN
#   e/NN
#    /VBD
#   1/CD
#   8/CD
#   3/CD
#   ,/,
#   0/CD
#   0/CD
#   0/CD
#    /NN
#   f/NN
#   e/NN
#   w/NN
#   e/NN
#   r/NN
#   (Chunk  /NNP)
#   e/VBZ
#   m/FW
#   p/NN
#   l/NN
#   o/NN
#   y/NN
#   e/NN
#   e/NN
#   s/NN
#   ;/:
#    /CC
#   t/VB
#   h/NN
#   u/JJ
#   s/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP d/NN)
#   i/NN
#   s/VBP
#   c/NN
#   o/NN
#   u/JJ
#   r/NN
#   a/DT
#   g/NN
#   i/NN
#   n/VBP
#   g/NN
#    /NN
#   t/NN
#   r/NN
#   e/NN
#   n/JJ
#   d/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP m/NN)
#   o/NN
#   d/NN
#   e/NN
#   r/NN
#   n/JJ
#   (Chunk  /NNP g/NN)
#   o/NN
#   v/NN
#   e/NN
#   r/NN
#   n/JJ
#   m/NN
#   e/NN
#   n/JJ
#   t/NN
#   s/NN
#   (Chunk  /NNP t/NN)
#   o/NN
#   w/VBD
#   a/DT
#   r/NN
#   d/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   i/NN
#   r/VBP
#    /JJ
#   o/NN
#   w/NN
#   n/JJ
#   (Chunk  /NNP l/NN)
#   i/NN
#   m/VBP
#   i/NN
#   t/VBP
#   l/NN
#   e/NN
#   s/NN
#   s/NN
#   (Chunk  /NNP e/NN)
#   (Chunk x/NNP)
#   p/VBZ
#   a/DT
#   n/JJ
#   s/NN
#   i/NN
#   o/VBP
#   n/JJ
#   (Chunk  /NNP h/NN)
#   a/DT
#   s/JJ
#    /NN
#   i/NN
#   n/VBP
#    /JJ
#   o/NN
#   u/JJ
#   r/NN
#   (Chunk  /NNP)
#   c/VBZ
#   a/DT
#   s/JJ
#   e/NN
#    /NN
#   b/NN
#   e/NN
#   e/NN
#   n/JJ
#   (Chunk  /NNP r/NN)
#   e/NN
#   v/NN
#   e/NN
#   r/NN
#   s/NN
#   e/NN
#   d/NN
#   ./.
#
# /JJ
#   (Chunk T/NNP h/NN)
#   e/NN
#   (Chunk  /NNP)
#   c/VBZ
#   o/JJ
#   s/JJ
#   t/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#    /IN
#   a/DT
#   r/NN
#   m/NN
#   a/DT
#   m/NN
#   e/NN
#   n/JJ
#   t/NN
#   s/NN
#    /NN
#   b/NN
#   e/NN
#   c/NN
#   o/IN
#   m/JJ
#   e/NN
#   s/NN
#   (Chunk  /NNP l/NN)
#   e/NN
#   s/NN
#   s/NN
#   (Chunk  /NNP)
#   o/VBZ
#   p/NN
#   p/NN
#   r/NN
#   e/NN
#   s/VBD
#   s/JJ
#   i/NN
#   v/VBP
#   e/NN
#    /VBP
#   a/DT
#   s/NN
#   (Chunk  /NNP w/NN)
#   e/NN
#   (Chunk  /NNP)
#   n/RB
#   e/VBZ
#   a/DT
#   r/NN
#   (Chunk  /NNP o/NN)
#   u/JJ
#   r/NN
#   (Chunk  /NNP d/NN)
#   e/NN
#   f/JJ
#   e/NN
#   n/JJ
#   s/NN
#   e/NN
#   (Chunk  /NNP g/NN)
#   o/VBD
#   a/DT
#   l/NN
#   s/NN
#   ;/:
#    /CC
#   y/VB
#   e/NN
#   t/NN
#   (Chunk  /NNP w/NN)
#   e/NN
#    /VBZ
#   a/DT
#   r/NN
#   e/NN
#   (Chunk  /NNP m/NN)
#   i/NN
#   l/VBP
#   i/NN
#   t/VBP
#   a/DT
#   r/NN
#   i/NN
#   l/VBP
#   y/NN
#   (Chunk  /NNP s/NN)
#   t/NN
#   r/NN
#   o/NN
#   n/JJ
#   g/NN
#   e/NN
#   r/NN
#   (Chunk  /NNP e/NN)
#   v/NN
#   e/NN
#   r/NN
#   y/NN
#   (Chunk  /NNP)
#   d/VBZ
#   a/DT
#   y/NN
#   ./.
#    /CC
#   (Chunk D/NNP)
#   u/JJ
#   r/NN
#   i/NN
#   n/VBP
#   g/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP y/NNP)
#   e/VBZ
#   a/DT
#   r/NN
#   ,/,
#   (Chunk  /NNP)
#   c/VBZ
#   r/NN
#   e/VBZ
#   a/DT
#   t/NN
#   i/NN
#   o/VBP
#   n/JJ
#   (Chunk  /NNP o/NN)
#   f/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP)
#   n/CC
#   e/JJ
#   w/NN
#   (Chunk  /NNP C/NNP)
#   a/DT
#   b/NN
#   i/NN
#   n/VBP
#   e/NN
#   t/NN
#   (Chunk  /NNP D/NNP)
#   e/VBZ
#   p/VB
#   a/DT
#   r/NN
#   t/NN
#   m/NN
#   e/NN
#   n/JJ
#   t/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP H/NNP)
#   e/VBZ
#   a/DT
#   l/NN
#   t/NN
#   h/NN
#   ,/,
#   (Chunk  /NNP E/NNP)
#   d/VBZ
#   u/JJ
#   c/VB
#   a/DT
#   t/NN
#   i/NN
#   o/VBP
#   n/NN
#   ,/,
#    /VB
#   a/DT
#   n/JJ
#   d/NN
#   (Chunk  /NNP W/NNP e/NN)
#   l/NN
#   f/VBD
#   a/DT
#   r/NN
#   e/NN
#   (Chunk  /NNP s/NN)
#   y/NN
#   m/NN
#   b/NN
#   o/IN
#   l/NN
#   i/NN
#   z/VBP
#   e/NN
#   d/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP g/NN)
#   o/NN
#   v/NN
#   e/NN
#   r/NN
#   n/JJ
#   m/NN
#   e/NN
#   n/JJ
#   t/NN
#   '/POS
#   s/NN
#   (Chunk  /NNP p/NN)
#   e/NN
#   r/NN
#   m/VBD
#   a/DT
#   n/JJ
#   e/NN
#   n/JJ
#   t/NN
#   (Chunk  /NNP)
#   c/VBZ
#   o/JJ
#   n/JJ
#   c/NN
#   e/NN
#   r/NN
#   n/JJ
#   (Chunk  /NNP w/NN)
#   i/NN
#   t/VBP
#   h/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP h/NN)
#   u/JJ
#   m/VBZ
#   a/DT
#   n/JJ
#    /NN
#   p/NN
#   r/NN
#   o/NN
#   b/NN
#   l/NN
#   e/NN
#   m/NN
#   s/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP o/NN)
#   u/JJ
#   r/NN
#   (Chunk  /NNP c/NN)
#   i/NN
#   t/VBP
#   i/JJ
#   z/VBP
#   e/JJ
#   n/JJ
#   s/NN
#   ./.
#
# /CC
#   (Chunk S/NNP)
#   e/VBP
#   g/JJ
#   r/NN
#   e/NN
#   g/VBD
#   a/DT
#   t/NN
#   i/NN
#   o/VBP
#   n/IN
#    /NN
#   i/NN
#   n/VBP
#    /JJ
#   t/NN
#   h/NN
#   e/NN
#    /VBZ
#   a/DT
#   r/NN
#   m/NN
#   e/NN
#   d/NN
#   (Chunk  /NNP f/NN)
#   o/NN
#   r/NN
#   c/NN
#   e/NN
#   s/VBP
#    /PDT
#   a/DT
#   n/JJ
#   d/NN
#   (Chunk  /NNP)
#   o/VBZ
#   t/JJ
#   h/NN
#   e/NN
#   r/NN
#   (Chunk  /NNP F/NNP e/NN)
#   d/NN
#   e/NN
#   r/VBZ
#   a/DT
#   l/NN
#    /VBZ
#   a/DT
#   c/JJ
#   t/NN
#   i/NN
#   v/VBP
#   i/JJ
#   t/VBP
#   i/JJ
#   e/VBP
#   s/JJ
#    /NN
#   i/NN
#   s/VBP
#    /JJ
#   o/NN
#   n/JJ
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP)
#   w/VBZ
#   a/DT
#   y/NN
#   (Chunk  /NNP)
#   o/VBZ
#   u/JJ
#   t/NN
#   ./.
#    /CC
#   (Chunk W/NNP)
#   (Chunk e/VBP  /NNP)
#   h/VBD
#   a/DT
#   v/NN
#   e/NN
#    /VBZ
#   a/DT
#   l/NN
#   s/NN
#   o/NN
#   (Chunk  /NNP)
#   m/VBZ
#   a/DT
#   d/NN
#   e/NN
#   (Chunk  /NNP p/NN)
#   r/NN
#   o/NN
#   g/NN
#   r/NN
#   e/NN
#   s/NN
#   s/NN
#   (Chunk  /NNP t/NN)
#   o/NN
#   w/VBD
#   a/DT
#   r/NN
#   d/NN
#    /NN
#   i/NN
#   t/VBP
#   s/NN
#   (Chunk  /NNP e/NN)
#   l/NN
#   i/VBP
#   m/VBP
#   i/JJ
#   n/VBP
#   a/DT
#   t/NN
#   i/NN
#   o/VBP
#   n/IN
#    /NN
#   i/NN
#   n/VBP
#    /JJ
#   t/NN
#   h/NN
#   e/NN
#   (Chunk  /NNP D/NNP i/NN)
#   s/VBP
#   t/IN
#   r/NN
#   i/NN
#   c/VBP
#   t/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP C/NNP)
#   o/MD
#   l/VB
#   u/JJ
#   m/NN
#   b/NN
#   i/NN
#   a/DT
#   ./.
#    /JJ
#   (Chunk T/NNP h/NN)
#   e/NN
#   s/NN
#   e/NN
#    /VBZ
#   a/DT
#   r/NN
#   e/NN
#   (Chunk  /NNP s/NN)
#   t/NN
#   e/NN
#   p/NN
#   s/NN
#    /NN
#   i/NN
#   n/VBP
#    /JJ
#   t/NN
#   h/NN
#   e/NN
#   (Chunk  /NNP)
#   c/VBZ
#   o/JJ
#   n/IN
#   t/NN
#   i/NN
#   n/VBP
#   u/JJ
#   i/NN
#   n/VBP
#   g/NN
#   (Chunk  /NNP e/NN)
#   f/NN
#   f/NN
#   o/NN
#   r/NN
#   t/NN
#   (Chunk  /NNP t/NN)
#   o/NN
#   (Chunk  /NNP e/NN)
#   l/NN
#   i/VBP
#   m/VBP
#   i/JJ
#   n/VBP
#   a/DT
#   t/NN
#   e/NN
#    /NN
#   i/NN
#   n/VBP
#   t/NN
#   e/NN
#   r/NN
#   -/:
#   r/NN
#   a/DT
#   c/NN
#   i/NN
#   a/DT
#   l/NN
#   (Chunk  /NNP d/NN)
#   i/NN
#   f/VBP
#   f/NN
#   i/NN
#   c/VBP
#   u/JJ
#   l/NN
#   t/NN
#   y/NN
#   ./.
#
# /CC
#   (Chunk S/NNP)
#   o/VBP
#   m/NN
#   e/NN
#   (Chunk  /NNP d/NN)
#   e/NN
#   v/NN
#   e/NN
#   l/NN
#   o/NN
#   p/NN
#   m/NN
#   e/NN
#   n/JJ
#   t/NN
#   s/NN
#    /NN
#   b/NN
#   e/NN
#   y/NN
#   o/NN
#   n/JJ
#   d/NN
#   (Chunk  /NNP o/NN)
#   u/JJ
#   r/NN
#   (Chunk  /NNP s/NN)
#   h/NN
#   o/JJ
#   r/NN
#   e/NN
#   s/NN
#   (Chunk  /NNP)
#   h/VBZ
#   a/DT
#   v/NN
#   e/NN
#   (Chunk  /NNP b/NN)
#   e/NN
#   e/NN
#   n/JJ
#   (Chunk  /NNP e/NN)
#   q/NN
#   u/IN
#   a/DT
#   l/NN
#   l/NN
#   y/NN
#   (Chunk  /NNP e/NN)
#   n/RB
#   c/JJ
#   o/NN
#   u/JJ
#   r/NN
#   a/DT
#   g/NN
#   i/NN
#   n/VBP
#   g/NN
#   ./.
#    /CC
#   (Chunk C/NNP)
#   o/VBP
#   m/JJ
#   m/NN
#   u/JJ
#   n/NN
#   i/NN
#   s/VBP
#   t/NN
#    /VBP
#   a/DT
#   g/NN
#   g/NN
#   r/NN
#   e/NN
#   s/VBD
#   s/JJ
#   i/NN
#   o/VBP
#   n/NN
#   ,/,
#   (Chunk  /NNP)
#   h/VBZ
#   a/DT
#   l/NN
#   t/NN
#   e/NN
#   d/NN
#    /NN
#   i/NN
#   n/VBP
#    /JJ
#   (Chunk K/NNP o/NNP r/NN)
#   e/NN
#   a/DT
#   ,/,
#   (Chunk  /NNP)
#   c/VBZ
#   o/JJ
#   n/IN
#   t/NN
#   i/NN
#   n/VBP
#   u/JJ
#   e/NN
#   s/NN
#   (Chunk  /NNP t/NN)
#   o/NN
#   (Chunk  /NNP m/NN)
#   e/NN
#   e/NN
#   t/IN
#    /NN
#   i/NN
#   n/VBP
#    /NN
#   I/PRP
#   n/VBP
#   d/JJ
#   o/SYM
#   -/:
#   c/NN
#   h/NN
#   i/JJ
#   n/VBP
#   a/DT
#    /JJ
#   t/NN
#   h/NN
#   e/NN
#   (Chunk  /NNP v/NN)
#   i/NN
#   g/VBP
#   o/JJ
#   r/NN
#   o/NN
#   u/JJ
#   s/NN
#   (Chunk  /NNP r/NN)
#   e/NN
#   s/NN
#   i/NN
#   s/VBP
#   t/IN
#   a/DT
#   n/JJ
#   c/NN
#   e/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP F/NNP)
#   r/VBZ
#   a/DT
#   n/JJ
#   c/NN
#   e/NN
#    /VBZ
#   a/DT
#   n/JJ
#   d/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#    /VBZ
#   A/DT
#   s/JJ
#   s/NN
#   o/IN
#   c/NN
#   i/VBP
#   a/DT
#   t/NN
#   e/NN
#   d/NN
#   (Chunk  /NNP S/NNP)
#   t/VBD
#   a/DT
#   t/NN
#   e/NN
#   s/NN
#   ,/,
#    /VB
#   a/DT
#   s/JJ
#   s/NN
#   i/NN
#   s/VBP
#   t/NN
#   e/NN
#   d/NN
#    /NN
#   b/NN
#   y/NN
#   (Chunk  /NNP t/NN)
#   i/NN
#   m/VBP
#   e/NN
#   l/NN
#   y/NN
#    /IN
#   a/DT
#   i/JJ
#   d/NN
#   (Chunk  /NNP f/NN)
#   r/NN
#   o/IN
#   m/NN
#   (Chunk  /NNP o/NN)
#   u/JJ
#   r/NN
#   (Chunk  /NNP)
#   c/VBZ
#   o/JJ
#   u/JJ
#   n/NN
#   t/NN
#   r/NN
#   y/NN
#   ./.
#    /NN
#   I/PRP
#   n/VBP
#    /JJ
#   (Chunk W/NNP e/NN)
#   s/NN
#   t/NN
#   (Chunk  /NNP G/NNP e/NN)
#   r/NN
#   m/VBD
#   a/DT
#   n/JJ
#   y/NN
#   ,/,
#    /VBP
#   i/JJ
#   n/VBP
#    /NN
#   I/PRP
#   r/VBP
#   a/DT
#   n/NN
#   ,/,
#    /VB
#   a/DT
#   n/JJ
#   d/NN
#    /NN
#   i/NN
#   n/VBP
#    /JJ
#   o/NN
#   t/NN
#   h/NN
#   e/NN
#   r/NN
#    /VBZ
#   a/DT
#   r/NN
#   e/VBZ
#   a/DT
#   s/JJ
#    /NN
#   o/NN
#   f/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP w/NN)
#   o/NN
#   r/NN
#   l/NN
#   d/NN
#   ,/,
#   (Chunk  /NNP)
#   h/VBZ
#   e/VB
#   a/DT
#   r/NN
#   t/NN
#   e/NN
#   n/IN
#   i/JJ
#   n/VBP
#   g/JJ
#   (Chunk  /NNP p/NN)
#   o/NN
#   l/NN
#   i/NN
#   t/VBP
#   i/NN
#   c/VBP
#   a/DT
#   l/NN
#   (Chunk  /NNP v/NN)
#   i/NN
#   c/VBP
#   t/NN
#   o/IN
#   r/NN
#   i/NN
#   e/VBP
#   s/JJ
#   (Chunk  /NNP h/NN)
#   a/DT
#   v/NN
#   e/NN
#   (Chunk  /NNP b/NN)
#   e/NN
#   e/NN
#   n/JJ
#   (Chunk  /NNP w/NN)
#   o/NN
#   n/NN
#    /NN
#   b/NN
#   y/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP f/NN)
#   o/NN
#   r/NN
#   c/NN
#   e/NN
#   s/JJ
#   (Chunk  /NNP o/NN)
#   f/NN
#   (Chunk  /NNP)
#   s/VBZ
#   t/VB
#   a/DT
#   b/NN
#   i/NN
#   l/VBP
#   i/NN
#   t/VBP
#   y/NN
#    /VBP
#   a/DT
#   n/JJ
#   d/NN
#   (Chunk  /NNP f/NN)
#   r/NN
#   e/NN
#   e/NN
#   d/NN
#   o/JJ
#   m/NN
#   ./.
#    /CC
#   (Chunk S/NNP l/NN)
#   o/NN
#   w/NN
#   l/NN
#   y/NN
#    /NN
#   b/NN
#   u/JJ
#   t/NN
#   (Chunk  /NNP s/NN)
#   u/JJ
#   r/NN
#   e/NN
#   l/NN
#   y/NN
#   ,/,
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP f/NN)
#   r/NN
#   e/NN
#   e/NN
#   (Chunk  /NNP w/NN)
#   o/NN
#   r/NN
#   l/NN
#   d/NN
#   (Chunk  /NNP)
#   g/VBZ
#   a/DT
#   t/NN
#   h/NN
#   e/NN
#   r/NN
#   s/NN
#   (Chunk  /NNP s/NN)
#   t/NN
#   r/NN
#   e/NN
#   n/JJ
#   g/NN
#   t/NN
#   h/NN
#   ./.
#    /CC
#   (Chunk M/NNP)
#   e/VBP
#   a/DT
#   n/JJ
#   w/NN
#   h/NN
#   i/JJ
#   l/NN
#   e/NN
#   ,/,
#   (Chunk  /NNP)
#   f/VBZ
#   r/NN
#   o/''
#   m/NN
#    /NN
#   b/NN
#   e/NN
#   h/NN
#   i/JJ
#   n/VBP
#   d/JJ
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#    /NN
#   i/NN
#   r/VBP
#   o/JJ
#   n/JJ
#   (Chunk  /NNP c/NN)
#   u/JJ
#   r/NN
#   t/IN
#   a/DT
#   i/NN
#   n/NN
#   ,/,
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   r/NN
#   e/NN
#    /VBZ
#   a/DT
#   r/NN
#   e/NN
#   (Chunk  /NNP s/NN)
#   i/NN
#   g/VBP
#   n/JJ
#   s/NN
#   (Chunk  /NNP t/NN)
#   h/VBD
#   a/DT
#   t/NN
#   (Chunk  /NNP t/NN)
#   y/NN
#   r/VBZ
#   a/DT
#   n/JJ
#   n/NN
#   y/NN
#    /NN
#   i/NN
#   s/VBP
#    /NN
#   i/NN
#   n/VBP
#    /NN
#   t/NN
#   r/NN
#   o/NN
#   u/NN
#   b/NN
#   l/NN
#   e/NN
#    /VBZ
#   a/DT
#   n/JJ
#   d/NN
#   (Chunk  /NNP r/NN)
#   e/NN
#   m/NN
#   i/NN
#   n/VBP
#   d/NN
#   e/NN
#   r/NN
#   s/NN
#   (Chunk  /NNP t/NN)
#   h/VBD
#   a/DT
#   t/NN
#    /NN
#   i/NN
#   t/VBP
#   s/NN
#   (Chunk  /NNP s/NN)
#   t/NN
#   r/NN
#   u/JJ
#   c/NN
#   t/NN
#   u/JJ
#   r/NN
#   e/NN
#    /NN
#   i/NN
#   s/VBP
#    /PDT
#   a/DT
#   s/NN
#    /NN
#   b/IN
#   r/NN
#   i/NN
#   t/VBP
#   t/NN
#   l/NN
#   e/NN
#    /VBZ
#   a/DT
#   s/JJ
#    /NN
#   i/NN
#   t/VBP
#   s/NN
#   (Chunk  /NNP s/NN)
#   u/JJ
#   r/NN
#   f/VBD
#   a/DT
#   c/JJ
#   e/NN
#    /NN
#   i/NN
#   s/VBP
#    /NN
#   h/NN
#   a/DT
#   r/NN
#   d/NN
#   ./.
#
# /JJ
#   (Chunk T/NNP h/NN)
#   e/NN
#   r/NN
#   e/NN
#   (Chunk  /NNP)
#   h/VBZ
#   a/DT
#   s/NN
#    /NN
#   b/NN
#   e/NN
#   e/NN
#   n/IN
#    /NN
#   i/NN
#   (Chunk n/VBP  /NNP)
#   f/VBP
#   a/DT
#   c/NN
#   t/NN
#    /VBZ
#   a/DT
#    /NN
#   g/NN
#   r/NN
#   e/VBZ
#   a/DT
#   t/NN
#   (Chunk  /NNP s/NN)
#   t/NN
#   r/VBZ
#   a/DT
#   t/NN
#   e/NN
#   g/NN
#   i/NN
#   (Chunk c/VBP  /NNP)
#   c/VBP
#   h/VBZ
#   a/DT
#   n/JJ
#   g/NN
#   e/NN
#    /NN
#   i/NN
#   n/VBP
#    /JJ
#   t/NN
#   h/NN
#   e/NN
#   (Chunk  /NNP w/NN)
#   o/NN
#   r/NN
#   l/NN
#   d/NN
#   (Chunk  /NNP d/NN)
#   u/JJ
#   r/NN
#   i/NN
#   n/VBP
#   g/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP)
#   p/VBZ
#   a/DT
#   s/JJ
#   t/NN
#   (Chunk  /NNP y/NNP)
#   e/VBZ
#   a/DT
#   r/NN
#   ./.
#    /CC
#   (Chunk T/NNP)
#   h/VBP
#   a/DT
#   t/NN
#    /NN
#   p/NN
#   r/NN
#   e/IN
#   c/NN
#   i/NN
#   o/VBP
#   u/JJ
#   s/NN
#    /NN
#   i/NN
#   n/VBP
#   t/IN
#   a/DT
#   n/JJ
#   g/NN
#   i/NN
#   b/VBP
#   l/NN
#   e/NN
#   ,/,
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP i/NN)
#   n/VBP
#   i/JJ
#   t/VBP
#   i/VBP
#   a/DT
#   t/NN
#   i/NN
#   v/VBP
#   e/NN
#   ,/,
#    /VBP
#   i/JJ
#   s/VBP
#    /NN
#   b/NN
#   e/NN
#   c/NN
#   o/IN
#   m/NN
#   i/NN
#   n/VBP
#   g/NN
#   (Chunk  /NNP o/NN)
#   u/JJ
#   r/NN
#   s/NN
#   ./.
#    /CC
#   (Chunk O/NNP)
#   u/JJ
#   r/NN
#   (Chunk  /NNP p/NN)
#   o/NN
#   l/NN
#   i/NN
#   c/VBP
#   y/NN
#   ,/,
#   (Chunk  /NNP)
#   n/FW
#   o/NN
#   t/NN
#   (Chunk  /NNP l/NN)
#   i/NN
#   m/VBP
#   i/NN
#   t/VBP
#   e/NN
#   d/NN
#   (Chunk  /NNP t/NN)
#   o/NN
#   (Chunk  /NNP m/NN)
#   e/NN
#   r/NN
#   e/NN
#   (Chunk  /NNP r/NN)
#   e/VBZ
#   a/DT
#   c/JJ
#   t/NN
#   i/NN
#   o/VBP
#   n/RB
#    /VBP
#   a/DT
#   g/NN
#   a/DT
#   i/NN
#   n/MD
#   s/VB
#   t/JJ
#   (Chunk  /NNP c/NN)
#   r/NN
#   i/NN
#   s/VBP
#   e/NN
#   s/NN
#   (Chunk  /NNP p/NN)
#   r/NN
#   o/NN
#   v/NN
#   o/NN
#   k/NN
#   e/FW
#   d/NN
#    /NN
#   b/NN
#   y/NN
#   (Chunk  /NNP)
#   o/VBZ
#   t/JJ
#   h/NN
#   e/NN
#   r/NN
#   s/NN
#   ,/,
#    /VBP
#   i/JJ
#   s/VBP
#    /JJ
#   f/NN
#   r/NN
#   e/NN
#   e/NN
#   (Chunk  /NNP t/NN)
#   o/NN
#   (Chunk  /NNP d/NN)
#   e/NN
#   v/NN
#   e/NN
#   l/NN
#   o/NN
#   p/NN
#    /VBZ
#   a/DT
#   l/NN
#   o/NN
#   n/JJ
#   g/NN
#   (Chunk  /NNP l/NN)
#   i/NN
#   n/VBP
#   e/NN
#   s/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP o/NN)
#   u/JJ
#   r/NN
#   (Chunk  /NNP c/NN)
#   h/NN
#   o/NN
#   i/NN
#   c/VBP
#   e/NN
#   (Chunk  /NNP)
#   n/CC
#   o/JJ
#   t/NN
#   (Chunk  /NNP)
#   o/VBZ
#   n/JJ
#   l/NN
#   y/NN
#    /VBZ
#   a/DT
#   b/NN
#   r/NN
#   o/IN
#   a/DT
#   d/NN
#   ,/,
#    /NN
#   b/NN
#   u/JJ
#   t/NN
#    /VBD
#   a/DT
#   l/NN
#   s/NN
#   o/NN
#    /VBZ
#   a/DT
#   t/NN
#    /NN
#   h/NN
#   o/JJ
#   m/NN
#   e/NN
#   ./.
#    /VB
#   A/DT
#   s/NN
#    /VBZ
#   a/DT
#    /JJ
#   m/NN
#   a/DT
#   j/NN
#   o/NN
#   r/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   m/NN
#   e/NN
#   (Chunk  /NNP f/NN)
#   o/NN
#   r/NN
#   (Chunk  /VBZ A/NNP m/NN)
#   e/NN
#   r/NN
#   i/NN
#   c/VBP
#   a/DT
#   n/JJ
#    /NN
#   p/NN
#   o/IN
#   l/NN
#   i/NN
#   c/VBP
#   y/NN
#   (Chunk  /NNP d/NN)
#   u/JJ
#   r/NN
#   i/NN
#   n/VBP
#   g/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP)
#   c/VBZ
#   o/IN
#   m/NN
#   i/NN
#   n/VBP
#   g/NN
#   (Chunk  /NNP y/NNP)
#   e/VBZ
#   a/DT
#   r/NN
#   ,/,
#   (Chunk  /NNP l/NN)
#   e/NN
#   t/NN
#   (Chunk  /NNP o/NN)
#   u/JJ
#   r/NN
#   (Chunk  /NNP j/NN)
#   o/NN
#   i/NN
#   n/VBP
#   t/NN
#   (Chunk  /NNP d/NN)
#   e/NN
#   t/NN
#   e/NN
#   r/NN
#   m/NN
#   i/NN
#   n/VBP
#   a/DT
#   t/NN
#   i/NN
#   o/VBP
#   n/JJ
#    /NN
#   b/NN
#   e/NN
#   (Chunk  /NNP t/NN)
#   o/NN
#   (Chunk  /NNP h/NN)
#   o/NN
#   l/NN
#   d/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   i/JJ
#   s/VBP
#    /JJ
#   n/JJ
#   e/NN
#   w/IN
#    /NN
#   i/NN
#   n/VBP
#   i/JJ
#   t/VBP
#   i/VBP
#   a/DT
#   t/NN
#   i/NN
#   v/VBP
#   e/NN
#    /VBP
#   a/DT
#   n/JJ
#   d/NN
#   (Chunk  /NNP t/NN)
#   o/NN
#   (Chunk  /NNP)
#   u/JJ
#   s/NN
#   e/NN
#    /NN
#   i/NN
#   t/NN
#   ./.
#
# /CC
#   (Chunk W/NNP)
#   (Chunk e/VBP  /NNP s/NN)
#   h/VBD
#   a/DT
#   l/NN
#   l/NN
#   (Chunk  /NNP)
#   u/JJ
#   s/NN
#   e/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   i/JJ
#   s/VBP
#    /NN
#   i/NN
#   n/VBP
#   i/JJ
#   t/VBP
#   i/VBP
#   a/DT
#   t/NN
#   i/NN
#   v/VBP
#   e/NN
#   (Chunk  /NNP t/NN)
#   o/NN
#   (Chunk  /NNP p/NN)
#   r/NN
#   o/IN
#   m/NN
#   o/NN
#   t/NN
#   e/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   r/NN
#   e/NN
#   e/NN
#    /NN
#   b/NN
#   r/NN
#   o/IN
#   a/DT
#   d/NN
#   (Chunk  /NNP p/NN)
#   u/JJ
#   r/NN
#   p/NN
#   o/NN
#   s/NN
#   e/NN
#   s/NN
#   :/:
#    /JJ
#   (Chunk F/NNP i/NN)
#   r/VBP
#   s/NN
#   t/NN
#   ,/,
#   (Chunk  /NNP)
#   t/VBZ
#   o/JJ
#   (Chunk  /NNP p/NN)
#   r/NN
#   o/NN
#   t/NN
#   e/NN
#   c/VBP
#   t/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP f/NN)
#   r/NN
#   e/NN
#   e/NN
#   d/NN
#   o/IN
#   m/JJ
#   (Chunk  /NNP o/NN)
#   f/NN
#   (Chunk  /NNP o/NN)
#   u/JJ
#   r/NN
#   (Chunk  /NNP p/NN)
#   e/NN
#   o/IN
#   p/NN
#   l/NN
#   e/NN
#   ;/:
#    /CC
#   s/VB
#   e/JJ
#   c/NNS
#   o/VBP
#   n/JJ
#   d/NN
#   ,/,
#   (Chunk  /NNP)
#   t/VBZ
#   o/JJ
#   (Chunk  /NNP)
#   m/VBD
#   a/DT
#   i/JJ
#   n/NN
#   t/IN
#   a/DT
#   i/JJ
#   n/NN
#    /VBD
#   a/DT
#    /JJ
#   s/NN
#   t/NN
#   r/NN
#   o/NN
#   n/JJ
#   g/NN
#   ,/,
#   (Chunk  /NNP g/NN)
#   r/NN
#   o/IN
#   w/NN
#   i/NN
#   n/VBP
#   g/NN
#   (Chunk  /NNP)
#   e/VBZ
#   c/JJ
#   o/JJ
#   n/JJ
#   o/NN
#   m/NN
#   y/NN
#   ;/:
#    /CC
#   t/IN
#   h/NN
#   i/NN
#   r/VBP
#   d/NN
#   ,/,
#   (Chunk  /NNP)
#   t/VBZ
#   o/JJ
#   (Chunk  /NNP c/NN)
#   o/NN
#   n/JJ
#   c/NN
#   e/NN
#   r/NN
#   n/JJ
#   (Chunk  /NNP o/NN)
#   u/JJ
#   r/NN
#   s/NN
#   e/NN
#   l/NN
#   v/NN
#   e/NN
#   s/NN
#   (Chunk  /NNP w/NN)
#   i/NN
#   t/VBP
#   h/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP h/NN)
#   u/JJ
#   m/VBZ
#   a/DT
#   n/JJ
#    /NN
#   p/NN
#   r/NN
#   o/NN
#   b/NN
#   l/NN
#   e/NN
#   m/NN
#   s/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP i/NN)
#   n/VBP
#   d/NN
#   i/NN
#   v/VBP
#   i/NN
#   d/VBP
#   u/IN
#   a/DT
#   l/NN
#   (Chunk  /NNP c/NN)
#   i/NN
#   t/VBP
#   i/JJ
#   z/VBP
#   e/JJ
#   n/NN
#   ./.
#
# /CC
#   (Chunk O/NNP)
#   n/VBP
#   l/NN
#   y/NN
#    /NN
#   b/NN
#   y/NN
#    /VBZ
#   a/DT
#   c/JJ
#   t/NN
#   i/NN
#   v/VBP
#   e/NN
#   (Chunk  /NNP)
#   c/VBZ
#   o/JJ
#   n/JJ
#   c/NN
#   e/NN
#   r/NN
#   n/JJ
#   (Chunk  /NNP f/NN)
#   o/NN
#   r/NN
#   (Chunk  /NNP)
#   e/VBZ
#   a/DT
#   c/NN
#   h/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   s/NN
#   e/NN
#   (Chunk  /NNP p/NN)
#   u/JJ
#   r/NN
#   p/NN
#   o/NN
#   s/NN
#   e/NN
#   s/NN
#   (Chunk  /NNP)
#   c/VBZ
#   a/DT
#   n/JJ
#    /NN
#   w/NN
#   e/NN
#   (Chunk  /NNP b/NN)
#   e/NN
#   (Chunk  /NNP s/NN)
#   u/JJ
#   r/NN
#   e/NN
#   (Chunk  /NNP t/NN)
#   h/VBD
#   a/DT
#   t/NN
#   (Chunk  /NNP w/NN)
#   e/NN
#    /VBZ
#   a/DT
#   r/NN
#   e/NN
#   (Chunk  /NNP)
#   o/VBZ
#   n/JJ
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP f/NN)
#   o/NN
#   r/NN
#   w/VBD
#   a/DT
#   r/NN
#   d/NN
#   (Chunk  /NNP r/NN)
#   o/VBD
#   a/DT
#   d/NN
#   (Chunk  /NNP t/NN)
#   o/NN
#    /VBZ
#   a/DT
#    /NN
#   b/NN
#   e/NN
#   t/NN
#   t/NN
#   e/NN
#   r/NN
#    /VBZ
#   a/DT
#   n/JJ
#   d/NN
#    /VBD
#   a/DT
#    /JJ
#   s/NN
#   t/NN
#   r/NN
#   o/NN
#   n/JJ
#   g/NN
#   e/NN
#   r/NN
#   (Chunk  /VBZ A/NNP m/NN)
#   e/NN
#   r/NN
#   i/NN
#   c/VBP
#   a/DT
#   ./.
#    /VB
#   A/DT
#   l/NN
#   l/NN
#   (Chunk  /NNP m/NN)
#   y/NN
#   (Chunk  /NNP r/NN)
#   e/NN
#   c/VBP
#   o/JJ
#   m/NN
#   m/NN
#   e/NN
#   n/JJ
#   d/VBZ
#   a/DT
#   t/NN
#   i/NN
#   o/VBP
#   n/JJ
#   s/NN
#   (Chunk  /NNP t/NN)
#   o/NN
#   d/VBZ
#   a/DT
#   y/NN
#    /VBZ
#   a/DT
#   r/NN
#   e/NN
#    /NN
#   i/NN
#   n/VBP
#    /JJ
#   f/NN
#   u/JJ
#   r/NN
#   t/NN
#   h/NN
#   e/NN
#   r/VBZ
#   a/DT
#   n/JJ
#   c/NN
#   e/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   s/NN
#   e/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   r/NN
#   e/NN
#   e/NN
#   (Chunk  /NNP p/NN)
#   u/JJ
#   r/NN
#   p/NN
#   o/NN
#   s/NN
#   e/NN
#   s/NN
#   ./.
#
# /JJ
#
# /NN
#   I/PRP
#   ./.
#   (Chunk  /VB F/NNP O/NNP R/NNP E/NNP)
#   I/PRP
#   (Chunk G/NNP N/NNP)
#   (Chunk  /VBZ A/NNP F/NNP F/NNP A/NNP)
#   I/PRP
#   (Chunk R/NNP S/NNP)
#   (Chunk
# /VBZ A/NNP m/NN)
#   e/NN
#   r/NN
#   i/NN
#   c/VBP
#   a/DT
#   n/JJ
#    /NN
#   f/NN
#   r/NN
#   e/NN
#   e/NN
#   d/NN
#   o/IN
#   m/JJ
#    /NN
#   i/NN
#   s/VBP
#    /JJ
#   t/NN
#   h/NN
#   r/NN
#   e/VBZ
#   a/DT
#   t/NN
#   e/NN
#   n/JJ
#   e/NN
#   d/NN
#   (Chunk  /NNP s/NN)
#   o/NN
#   (Chunk  /NNP l/NN)
#   o/NN
#   n/JJ
#   g/NN
#    /VBD
#   a/DT
#   s/JJ
#    /NN
#   t/NN
#   h/NN
#   e/NN
#   (Chunk  /NNP w/NN)
#   o/NN
#   r/NN
#   l/NN
#   d/NN
#   (Chunk  /NNP C/NNP)
#   o/MD
#   m/VB
#   m/NN
#   u/JJ
#   n/NN
#   i/NN
#   s/VBP
#   t/NN
#   (Chunk  /NNP)
#   c/VBZ
#   o/JJ
#   n/JJ
#   s/NN
#   p/NN
#   i/NN
#   r/VBP
#   a/DT
#   c/NN
#   y/NN
#   (Chunk  /NNP e/NN)
#   x/NN
#   i/NN
#   s/VBP
#   t/NN
#   s/NN
#    /NN
#   i/NN
#   n/VBP
#    /NN
#   i/NN
#   t/VBP
#   s/NN
#    /NN
#   p/NN
#   r/NN
#   e/NN
#   s/NN
#   e/NN
#   n/JJ
#   t/NN
#   (Chunk  /NNP)
#   s/VBZ
#   c/JJ
#   o/JJ
#   p/NN
#   e/NN
#   ,/,
#   (Chunk  /NNP)
#   p/VBZ
#   o/JJ
#   w/NN
#   e/NN
#   r/NN
#    /VBZ
#   a/DT
#   n/JJ
#   d/NN
#   (Chunk  /NNP h/NN)
#   o/NN
#   s/NN
#   t/NN
#   i/NN
#   l/VBP
#   i/NN
#   t/VBP
#   y/NN
#   ./.
#    /CC
#   (Chunk M/NNP)
#   o/VBP
#   r/NN
#   e/NN
#   (Chunk  /NNP)
#   c/VBZ
#   l/JJ
#   o/JJ
#   s/NN
#   e/NN
#   l/NN
#   y/NN
#   (Chunk  /NNP t/NN)
#   h/VBD
#   a/DT
#   n/JJ
#    /NN
#   e/NN
#   v/NN
#   e/NN
#   r/NN
#    /NN
#   b/NN
#   e/NN
#   f/NN
#   o/NN
#   r/NN
#   e/NN
#   ,/,
#   (Chunk  /VB A/NNP m/NN)
#   e/NN
#   r/NN
#   i/NN
#   c/VBP
#   a/DT
#   n/JJ
#    /NN
#   f/NN
#   r/NN
#   e/NN
#   e/NN
#   d/NN
#   o/IN
#   m/JJ
#    /NN
#   i/NN
#   s/VBP
#    /NN
#   i/NN
#   n/VBP
#   t/NN
#   e/NN
#   r/NN
#   l/NN
#   o/IN
#   c/JJ
#   k/NN
#   e/NN
#   d/NN
#   (Chunk  /NNP w/NN)
#   i/NN
#   t/VBP
#   h/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP f/NN)
#   r/NN
#   e/NN
#   e/NN
#   d/NN
#   o/IN
#   m/JJ
#   (Chunk  /NNP o/NN)
#   f/NN
#   (Chunk  /NNP)
#   o/VBZ
#   t/JJ
#   h/NN
#   e/NN
#   r/NN
#   (Chunk  /NNP p/NN)
#   e/NN
#   o/IN
#   p/NN
#   l/NN
#   e/NN
#   ./.
#    /NN
#   I/PRP
#   n/VBP
#    /JJ
#   t/NN
#   h/NN
#   e/NN
#   (Chunk  /NNP)
#   u/JJ
#   n/NN
#   i/NN
#   t/VBP
#   y/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP f/NN)
#   r/NN
#   e/NN
#   e/NN
#   (Chunk  /NNP w/NN)
#   o/NN
#   r/NN
#   l/NN
#   d/NN
#   (Chunk  /NNP l/NN)
#   i/NN
#   e/VBP
#   s/JJ
#   (Chunk  /NNP o/NN)
#   u/JJ
#   r/NN
#    /NN
#   b/NN
#   e/NN
#   s/NN
#   t/NN
#   (Chunk  /NNP)
#   c/VBZ
#   h/VB
#   a/DT
#   n/JJ
#   c/NN
#   e/NN
#   (Chunk  /NNP t/NN)
#   o/NN
#   (Chunk  /NNP r/NN)
#   e/NN
#   d/NN
#   u/JJ
#   c/NN
#   e/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP C/NNP)
#   o/MD
#   m/VB
#   m/NN
#   u/JJ
#   n/NN
#   i/NN
#   s/VBP
#   t/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   r/NN
#   e/VBZ
#   a/DT
#   t/NN
#   (Chunk  /NNP w/NN)
#   i/NN
#   t/VBP
#   h/NN
#   o/NN
#   u/JJ
#   t/NN
#   (Chunk  /NNP)
#   w/VBZ
#   a/DT
#   r/NN
#   ./.
#    /NN
#   I/PRP
#   n/VBP
#    /JJ
#   t/NN
#   h/NN
#   e/NN
#   (Chunk  /NNP)
#   t/VBZ
#   a/DT
#   s/JJ
#   k/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP)
#   m/VBD
#   a/DT
#   i/JJ
#   n/NN
#   t/IN
#   a/DT
#   i/JJ
#   n/NN
#   i/NN
#   n/VBP
#   g/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   i/JJ
#   s/VBP
#    /JJ
#   u/JJ
#   n/NN
#   i/NN
#   t/VBP
#   y/NN
#    /VBP
#   a/DT
#   n/JJ
#   d/NN
#   (Chunk  /NNP s/NN)
#   t/NN
#   r/NN
#   e/NN
#   n/JJ
#   g/NN
#   t/NN
#   h/NN
#   e/NN
#   n/IN
#   i/JJ
#   n/VBP
#   g/JJ
#    /FW
#   a/DT
#   l/NN
#   l/NN
#    /NN
#   i/NN
#   t/VBP
#   s/NN
#   (Chunk  /NNP)
#   p/VBZ
#   a/DT
#   r/NN
#   t/NN
#   s/NN
#   ,/,
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP g/NN)
#   r/NN
#   e/VBZ
#   a/DT
#   t/NN
#   e/NN
#   s/NN
#   t/NN
#   (Chunk  /NNP r/NN)
#   e/NN
#   s/NN
#   p/NN
#   o/NN
#   n/IN
#   s/NN
#   i/NN
#   b/VBP
#   i/NN
#   l/NN
#   i/NN
#   t/VBP
#   y/NN
#   (Chunk  /NNP)
#   f/VBZ
#   a/DT
#   l/NN
#   l/NN
#   s/NN
#   (Chunk  /NNP)
#   n/VBZ
#   a/DT
#   t/NN
#   u/JJ
#   r/NN
#   a/DT
#   l/NN
#   l/NN
#   y/NN
#   (Chunk  /NNP)
#   o/VBZ
#   n/JJ
#   (Chunk  /NNP t/NN)
#   h/NN
#   o/JJ
#   s/NN
#   e/NN
#   (Chunk  /NNP w/NN)
#   h/NN
#   o/NN
#   ,/,
#   (Chunk  /NNP l/NN)
#   i/NN
#   k/VBP
#   e/NN
#   (Chunk  /NNP o/NN)
#   u/JJ
#   r/NN
#   s/NN
#   e/NN
#   l/NN
#   v/NN
#   e/NN
#   s/NN
#   ,/,
#   (Chunk  /NNP r/NN)
#   e/NN
#   t/IN
#   a/DT
#   i/JJ
#   n/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP m/NN)
#   o/NN
#   s/NN
#   t/NN
#   (Chunk  /NNP f/NN)
#   r/NN
#   e/NN
#   e/NN
#   d/NN
#   o/IN
#   m/NN
#    /VBP
#   a/DT
#   n/JJ
#   d/NN
#   (Chunk  /NNP s/NN)
#   t/NN
#   r/NN
#   e/NN
#   n/JJ
#   g/NN
#   t/NN
#   h/NN
#   ./.
#
# /CC
#   (Chunk W/NNP)
#   (Chunk e/VBP  /NNP s/NN)
#   h/VBD
#   a/DT
#   l/NN
#   l/NN
#   ,/,
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   r/NN
#   e/NN
#   f/NN
#   o/NN
#   r/NN
#   e/NN
#   ,/,
#   (Chunk  /NNP)
#   c/VBZ
#   o/JJ
#   n/IN
#   t/NN
#   i/NN
#   n/VBP
#   u/JJ
#   e/NN
#   (Chunk  /NNP t/NN)
#   o/NN
#    /VBZ
#   a/DT
#   d/NN
#   v/NN
#   a/DT
#   n/JJ
#   c/NN
#   e/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP)
#   c/VBZ
#   a/DT
#   u/JJ
#   s/NN
#   e/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP f/NN)
#   r/NN
#   e/NN
#   e/NN
#   d/NN
#   o/IN
#   m/JJ
#   (Chunk  /NNP o/NN)
#   n/NN
#   (Chunk  /NNP f/NN)
#   o/NN
#   r/NN
#   e/NN
#   i/NN
#   g/VBP
#   n/JJ
#   (Chunk  /NNP f/NN)
#   r/NN
#   o/NN
#   n/JJ
#   t/NN
#   s/NN
#   ./.
#
# /NN
#   I/PRP
#   n/VBP
#    /JJ
#   t/NN
#   h/NN
#   e/NN
#   (Chunk  /NNP F/NNP)
#   a/DT
#   r/NN
#   (Chunk  /NNP E/NNP)
#   a/DT
#   s/NN
#   t/NN
#   ,/,
#   (Chunk  /NNP)
#   w/VBZ
#   e/FW
#   (Chunk  /NNP r/NN)
#   e/NN
#   t/IN
#   a/DT
#   i/JJ
#   n/NN
#   (Chunk  /NNP o/NN)
#   u/JJ
#   r/NN
#   (Chunk  /NNP v/NN)
#   i/NN
#   t/VBP
#   a/DT
#   l/NN
#    /NN
#   i/NN
#   n/VBP
#   t/NN
#   e/NN
#   r/NN
#   e/NN
#   s/NN
#   t/IN
#    /NN
#   i/NN
#   n/VBP
#    /JJ
#   (Chunk K/NNP o/NNP r/NN)
#   e/VBD
#   a/DT
#   ./.
#    /JJ
#   (Chunk W/NNP e/NN)
#   (Chunk  /NNP)
#   h/VBZ
#   a/DT
#   v/NN
#   e/NN
#   (Chunk  /NNP)
#   n/CC
#   e/JJ
#   g/NN
#   o/IN
#   t/NN
#   i/VBP
#   a/DT
#   t/NN
#   e/NN
#   d/NN
#   (Chunk  /NNP w/NN)
#   i/NN
#   t/VBP
#   h/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP R/NNP e/NN)
#   p/NN
#   u/NN
#   b/IN
#   l/NN
#   i/NN
#   c/VBP
#    /JJ
#   o/JJ
#   f/NN
#   (Chunk  /NNP K/NNP o/NNP r/NN)
#   e/VBZ
#   a/DT
#    /NN
#   a/DT
#    /JJ
#   m/NN
#   u/JJ
#   t/NN
#   u/IN
#   a/DT
#   l/NN
#   (Chunk  /NNP s/NN)
#   e/NN
#   c/NN
#   u/JJ
#   r/NN
#   i/NN
#   t/VBP
#   y/NN
#   (Chunk  /NNP)
#   p/VBZ
#   a/DT
#   c/NN
#   t/NN
#   ,/,
#   (Chunk  /NNP)
#   w/VBP
#   h/NN
#   i/JJ
#   c/VBP
#   h/JJ
#   (Chunk  /NNP d/NN)
#   e/NN
#   v/NN
#   e/NN
#   l/NN
#   o/NN
#   p/NN
#   s/NN
#   (Chunk  /NNP o/NN)
#   u/JJ
#   r/NN
#   (Chunk  /NNP s/NN)
#   e/NN
#   c/NN
#   u/JJ
#   r/NN
#   i/NN
#   t/VBP
#   y/NN
#   (Chunk  /NNP s/NN)
#   y/NN
#   s/NN
#   t/NN
#   e/NN
#   m/NN
#   (Chunk  /NNP f/NN)
#   o/NN
#   r/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP P/NNP)
#   a/DT
#   c/NN
#   i/NN
#   f/VBP
#   i/JJ
#   c/VBP
#    /PDT
#   a/DT
#   n/JJ
#   d/NN
#   (Chunk  /NNP w/NN)
#   h/NN
#   i/JJ
#   c/VBP
#   h/JJ
#    /NN
#   I/PRP
#    /VBP
#   s/JJ
#   h/NN
#   a/DT
#   l/NN
#   l/NN
#   (Chunk  /NNP p/NN)
#   r/NN
#   o/IN
#   m/NN
#   p/NN
#   t/NN
#   l/NN
#   y/NN
#   (Chunk  /NNP s/NN)
#   u/NN
#   b/IN
#   m/NN
#   i/NN
#   t/VBP
#    /JJ
#   t/NN
#   o/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP S/NNP)
#   e/VBZ
#   n/FW
#   a/DT
#   t/NN
#   e/NN
#   (Chunk  /NNP f/NN)
#   o/NN
#   r/NN
#    /NN
#   i/NN
#   t/VBP
#   s/NN
#   (Chunk  /NNP)
#   c/VBZ
#   o/JJ
#   n/JJ
#   s/NN
#   e/NN
#   n/JJ
#   t/NN
#   (Chunk  /NNP t/NN)
#   o/NN
#   (Chunk  /NNP)
#   r/VBZ
#   a/DT
#   t/NN
#   i/NN
#   f/VBP
#   i/NN
#   c/VBP
#   a/DT
#   t/NN
#   i/NN
#   o/VBP
#   n/NN
#   ./.
#    /CC
#   (Chunk W/NNP)
#   e/VBP
#    /VBZ
#   a/DT
#   r/NN
#   e/NN
#   (Chunk  /NNP p/NN)
#   r/NN
#   e/NN
#   p/VBZ
#   a/DT
#   r/NN
#   e/NN
#   d/NN
#   (Chunk  /NNP t/NN)
#   o/NN
#   (Chunk  /NNP m/NN)
#   e/NN
#   e/NN
#   t/NN
#    /VBZ
#   a/DT
#   n/JJ
#   y/NN
#   (Chunk  /NNP r/NN)
#   e/NN
#   n/JJ
#   e/NN
#   w/VBD
#   a/DT
#   l/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#    /IN
#   a/DT
#   r/NN
#   m/NN
#   e/NN
#   d/NN
#    /VBZ
#   a/DT
#   g/NN
#   g/NN
#   r/NN
#   e/NN
#   s/VBD
#   s/JJ
#   i/NN
#   o/VBP
#   n/IN
#    /NN
#   i/NN
#   n/VBP
#    /JJ
#   (Chunk K/NNP o/NNP r/NN)
#   e/VBD
#   a/DT
#   ./.
#    /JJ
#   (Chunk W/NNP e/NN)
#   (Chunk  /NNP s/NN)
#   h/VBD
#   a/DT
#   l/NN
#   l/NN
#   (Chunk  /NNP)
#   m/VBZ
#   a/DT
#   i/JJ
#   n/NN
#   t/IN
#   a/DT
#   i/JJ
#   n/JJ
#    /NN
#   i/NN
#   n/VBP
#   d/NN
#   e/NN
#   f/NN
#   i/NN
#   n/VBP
#   i/NN
#   t/VBP
#   e/NN
#   l/NN
#   y/NN
#   (Chunk  /NNP o/NN)
#   u/JJ
#   r/NN
#    /NN
#   b/VBD
#   a/DT
#   s/NN
#   e/NN
#   (Chunk s/VBD  /NNP i/NN)
#   n/VBP
#    /NN
#   (Chunk O/NNP k/NN)
#   i/NN
#   n/VBP
#   a/DT
#   w/NN
#   a/DT
#   ./.
#    /NN
#   I/PRP
#    /VBP
#   s/JJ
#   h/NN
#   a/DT
#   l/NN
#   l/NN
#    /VBZ
#   a/DT
#   s/JJ
#   k/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP C/NNP)
#   o/MD
#   n/VB
#   g/JJ
#   r/NN
#   e/NN
#   s/NN
#   s/NN
#   (Chunk  /NNP t/NN)
#   o/NN
#    /VBZ
#   a/DT
#   u/JJ
#   t/NN
#   h/NN
#   o/IN
#   r/NN
#   i/NN
#   z/VBP
#   e/NN
#   (Chunk  /NNP)
#   c/VBZ
#   o/JJ
#   n/IN
#   t/NN
#   i/NN
#   n/VBP
#   u/JJ
#   e/NN
#   d/NN
#   (Chunk  /NNP)
#   m/VBZ
#   a/DT
#   t/NN
#   e/NN
#   r/NN
#   i/VBZ
#   a/DT
#   l/NN
#    /VBZ
#   a/DT
#   s/JJ
#   s/NN
#   i/NN
#   s/VBP
#   t/IN
#   a/DT
#   n/JJ
#   c/NN
#   e/NN
#   (Chunk  /NNP t/NN)
#   o/NN
#   (Chunk  /NNP)
#   h/VBZ
#   a/DT
#   s/JJ
#   t/NN
#   e/NN
#   n/JJ
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP s/NN)
#   u/JJ
#   c/NN
#   c/NN
#   e/NN
#   s/JJ
#   s/NN
#   f/NN
#   u/JJ
#   l/NN
#   (Chunk  /NNP)
#   c/VBZ
#   o/JJ
#   n/JJ
#   c/NN
#   l/NN
#   u/JJ
#   s/NN
#   i/NN
#   o/VBP
#   n/JJ
#   (Chunk  /NNP o/NN)
#   f/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP s/NN)
#   t/NN
#   r/NN
#   u/JJ
#   g/NN
#   g/NN
#   l/NN
#   e/NN
#    /NN
#   i/NN
#   n/VBP
#    /NN
#   I/PRP
#   n/VBP
#   d/JJ
#   o/SYM
#   -/:
#   c/NN
#   h/NN
#   i/JJ
#   n/VBP
#   a/DT
#   ./.
#    /JJ
#   (Chunk T/NNP h/NN)
#   i/NN
#   s/VBP
#    /PDT
#   a/DT
#   s/JJ
#   s/NN
#   i/NN
#   s/VBP
#   t/IN
#   a/DT
#   n/JJ
#   c/NN
#   e/NN
#   (Chunk  /NNP w/NN)
#   i/NN
#   l/VBP
#   l/NN
#    /VBP
#   a/DT
#   l/NN
#   s/NN
#   o/NN
#    /NN
#   b/IN
#   r/NN
#   i/NN
#   n/VBP
#   g/NN
#   (Chunk  /NNP)
#   c/VBZ
#   l/JJ
#   o/JJ
#   s/NN
#   e/NN
#   r/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP)
#   d/VBZ
#   a/DT
#   y/NN
#   (Chunk  /NNP w/NN)
#   h/NN
#   e/NN
#   n/JJ
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#    /VBZ
#   A/DT
#   s/JJ
#   s/NN
#   o/IN
#   c/NN
#   i/VBP
#   a/DT
#   t/NN
#   e/NN
#   d/NN
#   (Chunk  /NNP S/NNP)
#   t/VBD
#   a/DT
#   t/NN
#   e/NN
#   s/NN
#   (Chunk  /NNP)
#   m/VBZ
#   a/DT
#   y/NN
#   (Chunk  /NNP e/NN)
#   n/RB
#   j/JJ
#   o/NN
#   y/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP i/NN)
#   n/VBP
#   d/NN
#   e/NN
#   p/NN
#   e/NN
#   n/JJ
#   d/NN
#   e/NN
#   n/JJ
#   c/NN
#   e/NN
#    /VBZ
#   a/DT
#   l/NN
#   r/NN
#   e/VBZ
#   a/DT
#   d/NN
#   y/NN
#    /VBZ
#   a/DT
#   s/JJ
#   s/NN
#   u/JJ
#   r/NN
#   e/NN
#   d/NN
#    /NN
#   b/NN
#   y/NN
#   (Chunk  /NNP F/NNP)
#   r/VBZ
#   a/DT
#   n/JJ
#   c/NN
#   e/NN
#   ./.
#    /CC
#   (Chunk W/NNP)
#   (Chunk e/VBP  /NNP s/NN)
#   h/VBD
#   a/DT
#   l/NN
#   l/NN
#    /VBZ
#   a/DT
#   l/NN
#   s/NN
#   o/NN
#   (Chunk  /NNP)
#   c/VBZ
#   o/JJ
#   n/IN
#   t/NN
#   i/NN
#   n/VBP
#   u/JJ
#   e/NN
#   (Chunk  /NNP m/NN)
#   i/NN
#   l/VBP
#   i/NN
#   t/VBP
#   a/DT
#   r/NN
#   y/NN
#    /VBZ
#   a/DT
#   n/JJ
#   d/NN
#   (Chunk  /NNP)
#   e/VBZ
#   c/JJ
#   o/JJ
#   n/JJ
#   o/IN
#   m/NN
#   i/NN
#   c/VBP
#    /IN
#   a/DT
#   i/JJ
#   d/NN
#   (Chunk  /NNP t/NN)
#   o/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP N/NNP)
#   a/DT
#   t/NN
#   i/NN
#   o/VBP
#   n/IN
#   a/DT
#   l/NN
#   i/NN
#   s/VBP
#   t/NN
#   (Chunk  /NNP G/NNP)
#   o/MD
#   v/VB
#   e/NN
#   r/NN
#   n/JJ
#   m/NN
#   e/NN
#   n/JJ
#   t/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP C/NNP h/NN)
#   i/NN
#   n/VBP
#   a/DT
#   ./.
#
# /NN
#   I/PRP
#   n/VBP
#    /JJ
#   (Chunk S/NNP o/NN)
#   u/JJ
#   t/NN
#   h/NN
#   (Chunk  /VBZ A/NNP s/NN)
#   i/NN
#   a/DT
#   ,/,
#    /NN
#   p/NN
#   r/NN
#   o/NN
#   f/NN
#   o/NN
#   u/JJ
#   n/JJ
#   d/NN
#   (Chunk  /NNP)
#   c/VBZ
#   h/VB
#   a/DT
#   n/JJ
#   g/NN
#   e/NN
#   s/NN
#    /VBZ
#   a/DT
#   r/NN
#   e/NN
#   (Chunk  /NNP)
#   t/VBZ
#   a/DT
#   k/NN
#   i/NN
#   n/VBP
#   g/NN
#   (Chunk  /NNP p/NN)
#   l/NN
#   a/DT
#   c/NN
#   e/NN
#   (Chunk  /NNP i/NN)
#   n/VBP
#    /NN
#   f/NN
#   r/NN
#   e/NN
#   e/NN
#   (Chunk  /NNP)
#   n/VBZ
#   a/DT
#   t/NN
#   i/NN
#   o/VBP
#   n/JJ
#   s/NN
#   (Chunk  /NNP w/NN)
#   h/NN
#   i/JJ
#   c/VBP
#   h/JJ
#    /FW
#   a/DT
#   r/NN
#   e/NN
#   (Chunk  /NNP d/NN)
#   e/NN
#   m/NN
#   o/NN
#   n/JJ
#   s/NN
#   t/NN
#   r/VBZ
#   a/DT
#   t/NN
#   i/NN
#   n/VBP
#   g/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   i/NN
#   r/VBP
#    /PDT
#   a/DT
#   b/NN
#   i/NN
#   l/VBP
#   i/NN
#   t/VBP
#   y/NN
#   (Chunk  /NNP t/NN)
#   o/NN
#   (Chunk  /NNP p/NN)
#   r/NN
#   o/NN
#   g/NN
#   r/NN
#   e/NN
#   s/NN
#   s/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   r/NN
#   o/NN
#   u/JJ
#   g/NN
#   h/NN
#   (Chunk  /NNP d/NN)
#   e/NN
#   m/NN
#   o/NN
#   c/VBP
#   r/VB
#   a/DT
#   t/NN
#   i/NN
#   c/VBP
#    /NN
#   (/(
#   (Chunk P/NNP g/NN)
#   ./.
#    /VB
#   9/CD
#   )/)
#    /FW
#   m/FW
#   e/FW
#   t/NN
#   h/NN
#   o/JJ
#   d/NN
#   s/NN
#   ./.
#    /CC
#   (Chunk T/NNP)
#   h/VBP
#   e/JJ
#   y/NN
#   (Chunk  /NNP p/NN)
#   r/NN
#   o/IN
#   v/NN
#   i/NN
#   d/VBP
#   e/NN
#    /VBP
#   a/DT
#   n/JJ
#    /NN
#   i/NN
#   n/VBP
#   s/JJ
#   p/NN
#   i/NN
#   r/VBP
#   i/NN
#   n/VBP
#   g/NN
#   (Chunk  /NNP)
#   c/VBZ
#   o/JJ
#   n/JJ
#   t/NN
#   r/NN
#   a/DT
#   s/JJ
#   t/NN
#   (Chunk  /NNP t/NN)
#   o/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP d/NN)
#   i/NN
#   c/VBP
#   t/IN
#   a/DT
#   t/NN
#   o/IN
#   r/NN
#   i/VBP
#   a/DT
#   l/NN
#   (Chunk  /NNP m/NN)
#   e/NN
#   t/NN
#   h/NN
#   o/JJ
#   d/NN
#   s/NN
#    /VBZ
#   a/DT
#   n/JJ
#   d/NN
#    /NN
#   b/VBD
#   a/DT
#   c/NN
#   k/NN
#   w/VBD
#   a/DT
#   r/NN
#   d/NN
#   (Chunk  /NNP)
#   c/VBZ
#   o/JJ
#   u/JJ
#   r/NN
#   s/NN
#   e/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP e/NN)
#   v/NN
#   e/NN
#   n/JJ
#   t/NN
#   s/NN
#    /NN
#   i/NN
#   (Chunk n/VBP  /NNP C/NNP)
#   o/MD
#   m/VB
#   m/NN
#   u/JJ
#   n/NN
#   i/NN
#   s/VBP
#   t/NN
#   (Chunk  /NNP C/NNP h/NN)
#   i/NN
#   n/VBP
#   a/DT
#   ./.
#    /NN
#   I/PRP
#   n/VBP
#    /JJ
#   t/NN
#   h/NN
#   e/NN
#   s/NN
#   e/NN
#   (Chunk  /NNP)
#   c/VBZ
#   o/JJ
#   n/IN
#   t/NN
#   i/NN
#   n/VBP
#   u/JJ
#   i/NN
#   n/VBP
#   g/NN
#   (Chunk  /NNP e/NN)
#   f/NN
#   f/NN
#   o/NN
#   r/NN
#   t/NN
#   s/NN
#   ,/,
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP f/NN)
#   r/NN
#   e/NN
#   e/NN
#   (Chunk  /NNP p/NN)
#   e/NN
#   o/IN
#   p/NN
#   l/NN
#   e/NN
#   s/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP S/NNP)
#   o/MD
#   u/VB
#   t/NN
#   h/NN
#   (Chunk  /VBZ A/NNP s/NN)
#   i/NN
#   a/DT
#   (Chunk  /NNP)
#   c/VBZ
#   a/DT
#   n/JJ
#    /NN
#   b/NN
#   e/NN
#    /VBZ
#   a/DT
#   s/JJ
#   s/NN
#   u/JJ
#   r/NN
#   e/NN
#   d/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP s/NN)
#   u/JJ
#   p/NN
#   p/NN
#   o/NN
#   r/NN
#   t/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP U/NNP n/NN)
#   i/NN
#   t/VBP
#   e/NN
#   d/NN
#   (Chunk  /NNP S/NNP)
#   t/VBD
#   a/DT
#   t/NN
#   e/NN
#   s/NN
#   ./.
#
# /NN
#   I/PRP
#   n/VBP
#    /JJ
#   t/NN
#   h/NN
#   e/NN
#   (Chunk  /NNP M/NNP i/NN)
#   d/VBP
#   d/NN
#   l/NN
#   e/NN
#   (Chunk  /NNP E/NNP)
#   a/DT
#   s/NN
#   t/NN
#   ,/,
#   (Chunk  /NNP)
#   w/VBZ
#   h/NN
#   e/NN
#   r/NN
#   e/NN
#   (Chunk  /NNP t/NN)
#   e/NN
#   n/IN
#   s/NN
#   i/NN
#   o/VBP
#   n/JJ
#   s/NN
#    /VBD
#   a/DT
#   n/JJ
#   d/NN
#   (Chunk  /NNP s/NN)
#   e/NN
#   r/NN
#   i/NN
#   o/VBP
#   u/JJ
#   s/NN
#   (Chunk  /NNP p/NN)
#   r/NN
#   o/NN
#   b/NN
#   l/NN
#   e/NN
#   m/NN
#   s/NN
#   (Chunk  /NNP e/NN)
#   x/NN
#   i/NN
#   s/VBP
#   t/NN
#   ,/,
#   (Chunk  /NNP)
#   w/VBZ
#   e/FW
#   (Chunk  /NNP w/NN)
#   i/NN
#   l/VBP
#   l/NN
#   (Chunk  /NNP s/NN)
#   h/NN
#   o/JJ
#   w/NN
#   (Chunk  /NNP s/NN)
#   y/NN
#   m/NN
#   p/VBZ
#   a/DT
#   t/NN
#   h/NN
#   e/NN
#   t/NN
#   i/NN
#   c/VBP
#    /PDT
#   a/DT
#   n/JJ
#   d/NN
#    /NN
#   i/NN
#   m/VBP
#   p/NN
#   a/DT
#   r/NN
#   t/NN
#   i/VBZ
#   a/DT
#   l/NN
#    /NN
#   f/VBP
#   r/NN
#   i/NN
#   e/VBP
#   n/JJ
#   d/NN
#   s/NN
#   h/NN
#   i/JJ
#   p/NN
#   ./.
#
# /NN
#   I/PRP
#   n/VBP
#    /JJ
#   (Chunk W/NNP e/NN)
#   s/NN
#   t/NN
#   e/NN
#   r/NN
#   n/JJ
#   (Chunk  /NNP E/NNP)
#   u/JJ
#   r/NN
#   o/NN
#   p/NN
#   e/NN
#   (Chunk  /NNP o/NN)
#   u/JJ
#   r/NN
#   (Chunk  /NNP p/NN)
#   o/NN
#   l/NN
#   i/NN
#   c/VBP
#   y/NN
#   (Chunk  /NNP r/NN)
#   e/NN
#   s/NN
#   t/NN
#   s/NN
#   (Chunk  /NNP f/NN)
#   i/NN
#   r/VBP
#   m/NN
#   l/NN
#   y/NN
#   (Chunk  /NNP)
#   o/VBZ
#   n/JJ
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP N/NNP)
#   o/MD
#   r/VB
#   t/NN
#   h/NN
#   (Chunk  /VBZ A/NNP t/NN)
#   l/NN
#   a/DT
#   n/JJ
#   t/NN
#   i/NN
#   c/VBP
#    /NN
#   (Chunk T/NNP r/NN)
#   e/VBZ
#   a/DT
#   t/JJ
#   y/NN
#   ./.
#    /NN
#   I/PRP
#   t/VBP
#    /JJ
#   w/NN
#   i/NN
#   l/VBP
#   l/NN
#   (Chunk  /NNP r/NN)
#   e/NN
#   m/VBD
#   a/DT
#   i/JJ
#   n/NN
#   (Chunk  /NNP s/NN)
#   o/NN
#   (Chunk  /NNP)
#   b/VBZ
#   a/DT
#   s/JJ
#   e/NN
#   d/NN
#    /VBZ
#   a/DT
#   s/JJ
#    /NN
#   f/VBD
#   a/DT
#   r/NN
#    /VBZ
#   a/DT
#   h/NN
#   e/VBZ
#   a/DT
#   d/NN
#    /VBZ
#   a/DT
#   s/JJ
#    /NN
#   w/NN
#   e/NN
#   (Chunk  /NNP)
#   c/VBZ
#   a/DT
#   n/JJ
#    /NN
#   s/NN
#   e/NN
#   e/NN
#   ./.
#    /JJ
#   (Chunk W/NNP i/NN)
#   t/VBP
#   h/NN
#   i/NN
#   n/VBP
#    /NN
#   i/NN
#   t/VBP
#   s/NN
#    /NN
#   o/NN
#   r/NN
#   g/VBD
#   a/DT
#   n/NN
#   i/NN
#   z/VBP
#   a/DT
#   t/NN
#   i/NN
#   o/VBP
#   n/NN
#   ,/,
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP b/NN)
#   u/NN
#   i/NN
#   l/VBP
#   d/NN
#   i/NN
#   n/VBP
#   g/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#    /IN
#   a/DT
#    /JJ
#   u/JJ
#   n/NN
#   i/NN
#   t/VBP
#   e/NN
#   d/NN
#   (Chunk  /NNP E/NNP)
#   u/JJ
#   r/NN
#   o/NN
#   p/NN
#   e/VBZ
#   a/DT
#   n/JJ
#   (Chunk  /NNP c/NN)
#   o/NN
#   m/NN
#   m/NN
#   u/JJ
#   n/NN
#   i/NN
#   t/VBP
#   y/NN
#   ,/,
#    /VBP
#   i/JJ
#   n/VBP
#   c/JJ
#   l/NN
#   u/JJ
#   d/NN
#   i/NN
#   n/VBP
#   g/NN
#    /NN
#   (Chunk F/NNP)
#   r/VBZ
#   a/DT
#   n/JJ
#   c/NN
#   e/NN
#    /VBZ
#   a/DT
#   n/JJ
#   d/NN
#   (Chunk  /NNP G/NNP e/NN)
#   r/NN
#   m/VBD
#   a/DT
#   n/JJ
#   y/NN
#   ,/,
#    /VBP
#   i/JJ
#   s/VBP
#    /JJ
#   v/NN
#   i/NN
#   t/VBP
#   a/DT
#   l/NN
#   (Chunk  /NNP t/NN)
#   o/NN
#    /VBZ
#   a/DT
#    /NN
#   f/NN
#   r/NN
#   e/NN
#   e/NN
#    /VBZ
#   a/DT
#   n/JJ
#   d/NN
#   (Chunk  /NNP s/NN)
#   e/NN
#   l/NN
#   f/SYM
#   -/:
#   r/NN
#   e/IN
#   l/NN
#   i/VBP
#   a/DT
#   n/JJ
#   t/NN
#   (Chunk  /NNP E/NNP)
#   u/JJ
#   r/NN
#   o/NN
#   p/NN
#   e/NN
#   ./.
#    /CC
#   (Chunk T/NNP)
#   h/VBP
#   i/JJ
#   s/VBP
#    /JJ
#   w/NN
#   i/NN
#   l/VBP
#   l/NN
#    /NN
#   b/NN
#   e/NN
#   (Chunk  /NNP p/NN)
#   r/NN
#   o/IN
#   m/NN
#   o/NN
#   t/NN
#   e/NN
#   d/NN
#    /NN
#   b/NN
#   y/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP E/NNP)
#   u/JJ
#   r/NN
#   o/NN
#   p/NN
#   e/VBZ
#   a/DT
#   n/JJ
#   (Chunk  /NNP D/NNP e/NN)
#   f/NN
#   e/NN
#   n/JJ
#   s/NN
#   e/NN
#   (Chunk  /NNP C/NNP)
#   o/MD
#   m/VB
#   m/NN
#   u/JJ
#   n/NN
#   i/NN
#   t/VBP
#   y/NN
#   (Chunk  /NNP w/NN)
#   h/NN
#   i/JJ
#   c/VBP
#   h/JJ
#   (Chunk  /NNP o/NN)
#   f/NN
#   f/NN
#   e/NN
#   r/NN
#   s/NN
#    /VBZ
#   a/DT
#   s/JJ
#   s/NN
#   u/JJ
#   r/NN
#   a/DT
#   n/JJ
#   c/NN
#   e/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP E/NNP)
#   u/JJ
#   r/NN
#   o/NN
#   p/NN
#   e/VBZ
#   a/DT
#   n/JJ
#    /NN
#   s/NN
#   e/NN
#   c/NN
#   u/JJ
#   r/NN
#   i/NN
#   t/VBP
#   y/NN
#   ./.
#    /JJ
#   (Chunk W/NNP i/NN)
#   t/VBP
#   h/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP)
#   c/VBZ
#   o/IN
#   m/NN
#   i/NN
#   n/VBP
#   g/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP u/NN)
#   n/NN
#   i/NN
#   t/VBP
#   y/NN
#   (Chunk  /NNP t/NN)
#   o/NN
#   (Chunk  /NNP W/NNP e/NN)
#   s/NN
#   t/NN
#   e/NN
#   r/NN
#   n/JJ
#   (Chunk  /NNP E/NNP)
#   u/JJ
#   r/NN
#   o/NN
#   p/NN
#   e/NN
#   ,/,
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#    /VBZ
#   a/DT
#   s/JJ
#   s/NN
#   i/NN
#   s/VBP
#   t/IN
#   a/DT
#   n/JJ
#   c/NN
#   e/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   i/JJ
#   s/VBP
#    /JJ
#   (Chunk N/NNP)
#   a/DT
#   t/NN
#   i/NN
#   o/VBP
#   n/JJ
#   (Chunk  /NNP)
#   c/VBZ
#   a/DT
#   n/JJ
#    /NN
#   r/NN
#   e/NN
#   n/JJ
#   d/NN
#   e/NN
#   r/NN
#   (Chunk  /NNP f/NN)
#   o/NN
#   r/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP s/NN)
#   e/NN
#   c/NN
#   u/JJ
#   r/NN
#   i/NN
#   t/VBP
#   y/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP E/NNP)
#   u/JJ
#   r/NN
#   o/NN
#   p/NN
#   e/NN
#    /VBZ
#   a/DT
#   n/JJ
#   d/NN
#   (Chunk  /NNP t/NN)
#   h/NN
# ...
#   i/NN
#   g/VBP
#   h/NN
#   t/NN
#   (Chunk  /NNP f/NN)
#   o/NN
#   r/NN
#   (Chunk  /VBZ A/NNP m/NN)
#   e/NN
#   r/NN
#   i/NN
#   c/VBP
#   a/DT
#   ./.
#    /JJ
#   (Chunk T/NNP h/NN)
#   e/NN
#   y/NN
#   (Chunk  /NNP s/NN)
#   h/NN
#   o/JJ
#   u/JJ
#   l/NN
#   d/NN
#   (Chunk  /NNP)
#   p/VBZ
#   a/DT
#   r/NN
#   t/NN
#   i/VBP
#   c/VBP
#   i/JJ
#   p/VBP
#   a/DT
#   t/NN
#   e/NN
#    /NN
#   i/NN
#   n/VBP
#    /JJ
#   t/NN
#   h/NN
#   e/NN
#   (Chunk  /NNP p/NN)
#   o/NN
#   l/NN
#   i/NN
#   t/VBP
#   i/NN
#   c/VBP
#   a/DT
#   l/NN
#    /NN
#   p/NN
#   r/NN
#   o/IN
#   c/JJ
#   e/NN
#   s/NN
#   s/NN
#   (Chunk  /NNP t/NN)
#   h/VBD
#   a/DT
#   t/NN
#    /NN
#   p/NN
#   r/NN
#   o/NN
#   d/NN
#   u/JJ
#   c/NN
#   e/NN
#   s/JJ
#   (Chunk  /NNP t/NN)
#   h/NN
#   i/JJ
#   s/VBP
#    /JJ
#   f/VBP
#   a/DT
#   t/NN
#   e/NN
#   f/NN
#   u/JJ
#   l/NN
#   (Chunk  /NNP s/NN)
#   u/JJ
#   m/NN
#   m/NN
#   o/NN
#   n/JJ
#   s/NN
#   ./.
#    /NN
#   I/PRP
#    /VBP
#   u/JJ
#   r/NN
#   g/NN
#   e/NN
#   (Chunk  /NNP C/NNP)
#   o/MD
#   n/VB
#   g/JJ
#   r/NN
#   e/NN
#   s/NN
#   s/NN
#   (Chunk  /NNP t/NN)
#   o/NN
#   (Chunk  /NNP p/NN)
#   r/NN
#   o/NN
#   p/NN
#   o/NN
#   s/NN
#   e/NN
#   (Chunk  /NNP t/NN)
#   o/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP S/NNP)
#   t/VBD
#   a/DT
#   t/NN
#   e/NN
#   s/NN
#    /VBZ
#   a/DT
#    /JJ
#   c/NN
#   o/NN
#   n/JJ
#   s/NN
#   t/NN
#   i/NN
#   t/VBP
#   u/JJ
#   t/NN
#   i/NN
#   o/VBP
#   n/IN
#   a/DT
#   l/NN
#    /VBZ
#   a/DT
#   m/NN
#   e/NN
#   n/JJ
#   d/NN
#   m/NN
#   e/NN
#   n/JJ
#   t/NN
#   (Chunk  /NNP p/NN)
#   e/NN
#   r/NN
#   m/NN
#   i/NN
#   t/VBP
#   t/NN
#   i/NN
#   n/VBP
#   g/NN
#   (Chunk  /NNP c/NN)
#   i/NN
#   t/VBP
#   i/JJ
#   z/VBP
#   e/JJ
#   n/JJ
#   s/NN
#   (Chunk  /NNP t/NN)
#   o/NN
#   (Chunk  /NNP v/NN)
#   o/NN
#   t/NN
#   e/NN
#   (Chunk  /NNP w/NN)
#   h/NN
#   e/NN
#   n/JJ
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   y/NN
#   (Chunk  /NNP r/NN)
#   e/VBZ
#   a/DT
#   c/NN
#   h/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#    /VBZ
#   a/DT
#   g/NN
#   e/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP)
#   1/CD
#   8/CD
#   ./.
#
# /VB
#
# /JJ
#   (Chunk C/NNP O/NNP N/NNP C/NNP L/NNP U/NNP S/NNP)
#   I/PRP
#   (Chunk O/NNP N/NNP
# /NNP)
#   I/PRP
#    /VBP
#   w/WRB
#   a/DT
#   n/JJ
#   t/NN
#   (Chunk  /NNP t/NN)
#   o/NN
#    /VBZ
#   a/DT
#   d/NN
#   d/NN
#   (Chunk  /NNP)
#   o/VBZ
#   n/JJ
#   e/NN
#   (Chunk  /NNP f/NN)
#   i/NN
#   n/VBP
#   a/DT
#   l/NN
#   (Chunk  /NNP w/NN)
#   o/NN
#   r/NN
#   d/NN
#    /VBZ
#   a/DT
#   b/NN
#   o/NN
#   u/JJ
#   t/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP g/NN)
#   e/NN
#   n/JJ
#   e/NN
#   r/VBZ
#   a/DT
#   l/NN
#   (Chunk  /NNP p/NN)
#   u/JJ
#   r/NN
#   p/NN
#   o/NN
#   r/NN
#   t/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   s/NN
#   e/NN
#   (Chunk  /NNP)
#   m/VBZ
#   a/DT
#   n/JJ
#   y/NN
#   (Chunk  /NNP r/NN)
#   e/NN
#   c/VBP
#   o/JJ
#   m/NN
#   m/NN
#   e/NN
#   n/JJ
#   d/VBZ
#   a/DT
#   t/NN
#   i/NN
#   o/VBP
#   n/JJ
#   s/NN
#   ./.
#
# /CC
#   (Chunk O/NNP)
#   u/JJ
#   r/NN
#   (Chunk  /NNP g/NN)
#   o/NN
#   v/NN
#   e/NN
#   r/NN
#   n/JJ
#   m/NN
#   e/NN
#   n/JJ
#   t/NN
#   '/POS
#   s/NN
#   (Chunk  /NNP p/NN)
#   o/NN
#   w/NN
#   e/NN
#   r/NN
#   s/NN
#    /VBZ
#   a/DT
#   r/NN
#   e/NN
#   (Chunk  /NNP w/NN)
#   i/NN
#   s/VBP
#   e/NN
#   l/NN
#   y/NN
#   (Chunk  /NNP l/NN)
#   i/NN
#   m/VBP
#   i/NN
#   t/VBP
#   e/NN
#   d/NN
#    /NN
#   b/NN
#   y/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP C/NNP)
#   o/MD
#   n/VB
#   s/JJ
#   t/NN
#   i/NN
#   t/VBP
#   u/JJ
#   t/NN
#   i/NN
#   o/VBP
#   n/RB
#   ;/:
#    /CC
#   b/VB
#   u/JJ
#   t/NN
#   (Chunk  /NNP q/NN)
#   u/NN
#   i/NN
#   t/VBP
#   e/NN
#    /VBP
#   a/DT
#   p/NN
#   a/DT
#   r/NN
#   t/NN
#   (Chunk  /NNP f/NN)
#   r/NN
#   o/IN
#   m/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   o/JJ
#   s/NN
#   e/NN
#   (Chunk  /NNP l/NN)
#   i/NN
#   m/VBP
#   i/NN
#   t/VBP
#   a/DT
#   t/NN
#   i/NN
#   o/VBP
#   n/JJ
#   s/NN
#   ,/,
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   r/NN
#   e/NN
#    /VBZ
#   a/DT
#   r/NN
#   e/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   i/JJ
#   n/VBP
#   g/JJ
#   s/NN
#   (Chunk  /NNP w/NN)
#   h/NN
#   i/JJ
#   c/VBP
#   h/JJ
#   (Chunk  /NNP n/NN)
#   o/NN
#   (Chunk  /NNP g/NN)
#   o/NN
#   v/NN
#   e/NN
#   r/NN
#   n/JJ
#   m/NN
#   e/NN
#   n/JJ
#   t/NN
#   (Chunk  /NNP)
#   c/VBZ
#   a/DT
#   n/JJ
#   (Chunk  /NNP d/NN)
#   o/NN
#   (Chunk  /NNP)
#   o/VBZ
#   r/NN
#   (Chunk  /NNP s/NN)
#   h/NN
#   o/JJ
#   u/JJ
#   l/NN
#   d/NN
#   (Chunk  /NNP t/NN)
#   r/NN
#   y/NN
#   (Chunk  /NNP t/NN)
#   o/NN
#   (Chunk  /NNP d/NN)
#   o/NN
#   ./.
#
# /VB
#   A/DT
#    /JJ
#   g/NN
#   o/NN
#   v/NN
#   e/NN
#   r/NN
#   n/JJ
#   m/NN
#   e/NN
#   n/JJ
#   t/NN
#   (Chunk  /NNP)
#   c/VBZ
#   a/DT
#   n/JJ
#    /NN
#   s/NN
#   t/IN
#   r/NN
#   i/NN
#   v/VBP
#   e/NN
#   ,/,
#    /VB
#   a/DT
#   s/JJ
#    /NN
#   o/NN
#   u/JJ
#   r/NN
#   s/NN
#    /NN
#   i/NN
#   s/VBP
#    /JJ
#   s/NN
#   t/NN
#   r/NN
#   i/NN
#   v/VBP
#   i/NN
#   n/VBP
#   g/NN
#   ,/,
#   (Chunk  /NNP)
#   t/VBZ
#   o/JJ
#   (Chunk  /NNP)
#   m/VBD
#   a/DT
#   i/JJ
#   n/NN
#   t/IN
#   a/DT
#   i/JJ
#   n/NN
#    /VBD
#   a/DT
#   n/JJ
#    /NN
#   e/NN
#   c/VBP
#   o/JJ
#   n/JJ
#   o/IN
#   m/NN
#   i/NN
#   c/VBP
#    /JJ
#   s/NN
#   y/NN
#   s/NN
#   t/NN
#   e/NN
#   m/NN
#   (Chunk  /NNP w/NN)
#   h/NN
#   o/JJ
#   s/NN
#   e/NN
#   (Chunk  /NNP d/NN)
#   o/NN
#   o/NN
#   r/NN
#   s/NN
#    /VBZ
#   a/DT
#   r/NN
#   e/NN
#   (Chunk  /NNP)
#   o/VBZ
#   p/JJ
#   e/NN
#   n/JJ
#   (Chunk  /NNP t/NN)
#   o/NN
#   (Chunk  /NNP e/NN)
#   n/RB
#   t/JJ
#   e/NN
#   r/NN
#   p/NN
#   r/NN
#   i/NN
#   s/VBP
#   e/NN
#    /VBP
#   a/DT
#   n/JJ
#   d/NN
#    /VBD
#   a/DT
#   m/NN
#   b/NN
#   i/NN
#   t/VBP
#   i/NN
#   o/VBP
#   n/SYM
#   -/:
#   -/:
#   t/NN
#   h/NN
#   o/JJ
#   s/NN
#   e/NN
#   (Chunk  /NNP p/NN)
#   e/NN
#   r/NN
#   s/NN
#   o/NN
#   n/IN
#   a/DT
#   l/NN
#   (Chunk  /NNP q/NN)
#   u/VBD
#   a/DT
#   l/NN
#   i/NN
#   t/VBP
#   i/NN
#   e/VBP
#   s/JJ
#   (Chunk  /NNP o/NN)
#   n/NN
#   (Chunk  /NNP w/NN)
#   h/NN
#   i/JJ
#   c/VBP
#   h/JJ
#   (Chunk  /NNP e/NN)
#   c/NN
#   o/NN
#   n/JJ
#   o/IN
#   m/NN
#   i/NN
#   c/VBP
#    /NN
#   g/NN
#   r/NN
#   o/NN
#   w/NN
#   t/NN
#   h/NN
#   (Chunk  /NNP)
#   l/VBZ
#   a/DT
#   r/NN
#   g/NN
#   e/NN
#   l/NN
#   y/NN
#   (Chunk  /NNP d/NN)
#   e/NN
#   p/NN
#   e/NN
#   n/JJ
#   d/NN
#   s/NN
#   ./.
#    /NN
#   (Chunk B/NNP u/NN)
#   t/NN
#   (Chunk  /NNP e/NN)
#   n/RB
#   t/JJ
#   e/NN
#   r/NN
#   p/NN
#   r/NN
#   i/NN
#   s/VBP
#   e/NN
#    /VBP
#   a/DT
#   n/JJ
#   d/NN
#    /VBD
#   a/DT
#   m/NN
#   b/NN
#   i/NN
#   t/VBP
#   i/NN
#   o/VBP
#   n/RB
#    /VBP
#   a/DT
#   r/NN
#   e/NN
#   (Chunk  /NNP q/NN)
#   u/VBD
#   a/DT
#   l/NN
#   i/NN
#   t/VBP
#   i/NN
#   e/VBP
#   s/JJ
#   (Chunk  /NNP w/NN)
#   h/NN
#   i/JJ
#   c/VBP
#   h/JJ
#   (Chunk  /NNP n/NN)
#   o/NN
#   (Chunk  /NNP g/NN)
#   o/NN
#   v/NN
#   e/NN
#   r/NN
#   n/JJ
#   m/NN
#   e/NN
#   n/JJ
#   t/NN
#   (Chunk  /NNP)
#   c/VBZ
#   a/DT
#   n/JJ
#    /NN
#   s/NN
#   u/JJ
#   p/NN
#   p/NN
#   l/NN
#   y/NN
#   ./.
#    /CC
#   (Chunk F/NNP)
#   o/VBP
#   r/NN
#   t/NN
#   u/JJ
#   n/VBZ
#   a/DT
#   t/NN
#   e/NN
#   l/NN
#   y/NN
#   (Chunk  /NNP)
#   n/CC
#   o/JJ
#    /NN
#   (Chunk A/NNP m/NN)
#   e/NN
#   r/NN
#   i/NN
#   c/VBP
#   a/DT
#   n/JJ
#    /NN
#   g/NN
#   o/NN
#   v/NN
#   e/NN
#   r/NN
#   n/JJ
#   m/NN
#   e/NN
#   n/JJ
#   t/NN
#   (Chunk  /NNP)
#   n/CC
#   e/JJ
#   e/NN
#   d/NN
#   (Chunk  /NNP)
#   c/VBZ
#   o/JJ
#   n/JJ
#   c/NN
#   e/NN
#   r/NN
#   n/IN
#    /NN
#   i/NN
#   t/VBP
#   s/NN
#   e/NN
#   l/NN
#   f/NN
#   (Chunk  /NNP)
#   o/VBZ
#   n/JJ
#   (Chunk  /NNP t/NN)
#   h/NN
#   i/JJ
#   s/VBP
#    /JJ
#   s/JJ
#   c/NN
#   o/NN
#   r/NN
#   e/NN
#   ;/:
#    /CC
#   o/MD
#   u/VB
#   r/NN
#   (Chunk  /NNP p/NN)
#   e/NN
#   o/IN
#   p/NN
#   l/NN
#   e/NN
#   (Chunk  /NNP)
#   h/VBZ
#   a/DT
#   v/NN
#   e/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   s/NN
#   e/NN
#   (Chunk  /NNP q/NN)
#   u/VBD
#   a/DT
#   l/NN
#   i/NN
#   t/VBP
#   i/NN
#   e/VBP
#   s/JJ
#    /NN
#   i/NN
#   n/VBP
#    /JJ
#   g/NN
#   o/NN
#   o/NN
#   d/NN
#   (Chunk  /NNP m/NN)
#   e/VBZ
#   a/DT
#   s/NN
#   u/JJ
#   r/NN
#   e/NN
#   ./.
#
# /VB
#   A/DT
#    /JJ
#   g/NN
#   o/NN
#   v/NN
#   e/NN
#   r/NN
#   n/JJ
#   m/NN
#   e/NN
#   n/JJ
#   t/NN
#   (Chunk  /NNP)
#   c/VBZ
#   a/DT
#   n/JJ
#    /NN
#   s/NN
#   i/NN
#   n/VBP
#   c/NN
#   e/NN
#   r/NN
#   e/NN
#   l/NN
#   y/NN
#   (Chunk  /NNP s/NN)
#   t/NN
#   r/NN
#   i/NN
#   v/VBP
#   e/NN
#   (Chunk  /NNP f/NN)
#   o/NN
#   r/NN
#   (Chunk  /NNP p/NN)
#   e/VBZ
#   a/DT
#   c/NN
#   e/NN
#   ,/,
#    /VB
#   a/DT
#   s/JJ
#    /NN
#   o/NN
#   u/JJ
#   r/NN
#   s/NN
#    /NN
#   i/NN
#   s/VBP
#    /JJ
#   s/NN
#   t/NN
#   r/NN
#   i/NN
#   v/VBP
#   i/NN
#   n/VBP
#   g/NN
#   ,/,
#    /VB
#   a/DT
#   n/JJ
#   d/NN
#    /VBD
#   a/DT
#   s/JJ
#   k/NN
#   (Chunk  /NNP i/NN)
#   t/VBP
#   s/NN
#   (Chunk  /NNP p/NN)
#   e/NN
#   o/IN
#   p/NN
#   l/NN
#   e/NN
#   (Chunk  /NNP t/NN)
#   o/NN
#   (Chunk  /NNP)
#   m/VBZ
#   a/DT
#   k/NN
#   e/NN
#   (Chunk  /NNP)
#   s/VBZ
#   a/DT
#   c/JJ
#   r/NN
#   i/NN
#   f/VBP
#   i/JJ
#   c/VBP
#   e/JJ
#   s/JJ
#    /NN
#   f/NN
#   o/NN
#   r/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP)
#   s/VBZ
#   a/DT
#   k/NN
#   e/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP p/NN)
#   e/VBZ
#   a/DT
#   c/JJ
#   e/NN
#   ./.
#    /NN
#   (Chunk B/NNP u/NN)
#   t/NN
#   (Chunk  /NNP)
#   n/CC
#   o/JJ
#   (Chunk  /NNP g/NN)
#   o/NN
#   v/NN
#   e/NN
#   r/NN
#   n/JJ
#   m/NN
#   e/NN
#   n/JJ
#   t/NN
#   (Chunk  /NNP)
#   c/VBZ
#   a/DT
#   n/JJ
#    /NN
#   p/NN
#   l/VBZ
#   a/DT
#   c/JJ
#   e/NN
#   (Chunk  /NNP p/NN)
#   e/VBZ
#   a/DT
#   c/JJ
#   e/NN
#    /NN
#   i/NN
#   n/VBP
#    /JJ
#   t/NN
#   h/NN
#   e/NN
#   (Chunk  /NNP h/NN)
#   e/VBZ
#   a/DT
#   r/NN
#   t/NN
#   s/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP f/NN)
#   o/NN
#   r/NN
#   e/NN
#   i/NN
#   g/VBP
#   n/JJ
#   (Chunk  /NNP r/NN)
#   u/JJ
#   l/NN
#   e/NN
#   r/NN
#   s/NN
#   ./.
#    /NN
#   I/PRP
#   t/VBP
#    /JJ
#   i/NN
#   s/VBP
#    /JJ
#   o/NN
#   u/JJ
#   r/NN
#   (Chunk  /NNP d/NN)
#   u/JJ
#   t/NN
#   y/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   n/JJ
#   (Chunk  /NNP t/NN)
#   o/NN
#   (Chunk  /NNP o/NN)
#   u/JJ
#   r/NN
#   s/NN
#   e/NN
#   l/NN
#   v/NN
#   e/NN
#   s/NN
#    /VBZ
#   a/DT
#   n/JJ
#   d/NN
#   (Chunk  /NNP t/NN)
#   o/NN
#   (Chunk  /NNP f/NN)
#   r/NN
#   e/NN
#   e/NN
#   d/NN
#   o/IN
#   m/JJ
#    /NN
#   i/NN
#   t/VBP
#   s/NN
#   e/NN
#   l/NN
#   f/NN
#   (Chunk  /NNP t/NN)
#   o/NN
#   (Chunk  /NNP r/NN)
#   e/NN
#   m/VBD
#   a/DT
#   i/JJ
#   n/NN
#   (Chunk  /NNP s/NN)
#   t/NN
#   r/NN
#   o/NN
#   n/JJ
#   g/NN
#    /NN
#   i/NN
#   n/VBP
#    /PDT
#   a/DT
#   l/NN
#   l/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   o/JJ
#   s/NN
#   e/NN
#   (Chunk  /NNP)
#   w/VBZ
#   a/DT
#   y/NN
#   s/SYM
#   -/:
#   -/:
#   s/NN
#   p/NN
#   i/NN
#   r/VBP
#   i/NN
#   t/VBP
#   u/IN
#   a/DT
#   l/NN
#   ,/,
#   (Chunk  /NNP)
#   e/VBZ
#   c/JJ
#   o/JJ
#   n/JJ
#   o/IN
#   m/NN
#   i/NN
#   c/VBP
#   ,/,
#    /JJ
#   m/NN
#   i/NN
#   l/VBP
#   i/NN
#   t/VBP
#   a/DT
#   r/NN
#   y/SYM
#   -/:
#   -/:
#   t/NN
#   h/VBZ
#   a/DT
#   t/NN
#   (Chunk  /NNP w/NN)
#   i/NN
#   l/VBP
#   l/NN
#   (Chunk  /NNP g/NN)
#   i/NN
#   v/VBP
#   e/NN
#   (Chunk  /NNP)
#   u/JJ
#   s/NN
#   (Chunk  /NNP)
#   m/VBZ
#   a/DT
#   x/NN
#   i/NN
#   m/VBP
#   u/JJ
#   m/NN
#   (Chunk  /NNP)
#   s/VBZ
#   a/DT
#   f/JJ
#   e/NN
#   t/NN
#   y/NN
#    /VBZ
#   a/DT
#   g/NN
#   a/DT
#   i/NN
#   n/MD
#   s/VB
#   t/JJ
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP p/NN)
#   o/NN
#   s/NN
#   s/NN
#   i/NN
#   b/VBP
#   i/NN
#   l/NN
#   i/NN
#   t/VBP
#   y/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#    /IN
#   a/DT
#   g/NN
#   g/NN
#   r/NN
#   e/NN
#   s/VBD
#   s/JJ
#   i/NN
#   v/VBP
#   e/NN
#    /VBP
#   a/DT
#   c/NN
#   t/NN
#   i/NN
#   o/VBP
#   n/JJ
#    /NN
#   b/NN
#   y/NN
#   (Chunk  /NNP)
#   o/VBZ
#   t/JJ
#   h/NN
#   e/NN
#   r/NN
#   s/NN
#   ./.
#
# /CC
#   (Chunk N/NNP)
#   (Chunk o/VBP  /NNP g/NN)
#   o/NN
#   v/NN
#   e/NN
#   r/NN
#   n/JJ
#   m/NN
#   e/NN
#   n/JJ
#   t/NN
#   (Chunk  /NNP)
#   c/VBZ
#   a/DT
#   n/JJ
#    /NN
#   i/NN
#   n/VBP
#   o/JJ
#   c/NN
#   u/JJ
#   l/VBZ
#   a/DT
#   t/NN
#   e/NN
#    /NN
#   i/NN
#   t/VBP
#   s/NN
#   (Chunk  /NNP p/NN)
#   e/NN
#   o/IN
#   p/NN
#   l/NN
#   e/NN
#    /VBZ
#   a/DT
#   g/NN
#   a/DT
#   i/NN
#   n/MD
#   s/VB
#   t/JJ
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP)
#   f/VBZ
#   a/DT
#   t/NN
#   a/DT
#   l/NN
#   (Chunk  /NNP)
#   m/VBZ
#   a/DT
#   t/NN
#   e/NN
#   r/NN
#   i/VBZ
#   a/DT
#   l/NN
#   i/NN
#   s/VBP
#   m/NN
#   (Chunk  /NNP t/NN)
#   h/VBD
#   a/DT
#   t/NN
#   (Chunk  /NNP p/NN)
#   l/NN
#   a/DT
#   g/NN
#   u/JJ
#   e/NN
#   s/NN
#   (Chunk  /NNP o/NN)
#   u/JJ
#   r/NN
#    /VBD
#   a/DT
#   g/NN
#   e/NN
#   ./.
#   (Chunk  /VB H/NNP)
#   a/DT
#   p/NN
#   p/NN
#   i/NN
#   l/VBP
#   y/NN
#   ,/,
#   (Chunk  /NNP)
#   o/MD
#   u/VB
#   r/NN
#   (Chunk  /NNP p/NN)
#   e/NN
#   o/IN
#   p/NN
#   l/NN
#   e/NN
#   ,/,
#   (Chunk  /NNP t/NN)
#   h/NN
#   o/JJ
#   u/JJ
#   g/NN
#   h/NN
#    /NN
#   b/NN
#   l/NN
#   e/NN
#   s/NN
#   s/NN
#   e/NN
#   d/NN
#   (Chunk  /NNP w/NN)
#   i/NN
#   t/VBP
#   h/NN
#   (Chunk  /NNP m/NN)
#   o/NN
#   r/NN
#   e/NN
#   (Chunk  /NNP)
#   m/VBZ
#   a/DT
#   t/NN
#   e/NN
#   r/NN
#   i/VBZ
#   a/DT
#   l/NN
#   (Chunk  /NNP g/NN)
#   o/NN
#   o/NN
#   d/NN
#   s/NN
#   (Chunk  /NNP t/NN)
#   h/VBD
#   a/DT
#   n/JJ
#    /NN
#   a/DT
#   n/JJ
#   y/NN
#   (Chunk  /NNP p/NN)
#   e/NN
#   o/IN
#   p/NN
#   l/NN
#   e/NN
#    /NN
#   i/NN
#   n/VBP
#    /IN
#   h/NN
#   i/NN
#   s/VBP
#   t/NN
#   o/NN
#   r/NN
#   y/NN
#   ,/,
#   (Chunk  /NNP)
#   h/VBZ
#   a/DT
#   v/NN
#   e/NN
#    /VBZ
#   a/DT
#   l/NN
#   w/WRB
#   a/DT
#   y/NN
#   s/NN
#   (Chunk  /NNP r/NN)
#   e/NN
#   s/NN
#   e/NN
#   r/NN
#   v/NN
#   e/NN
#   d/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   i/NN
#   r/VBP
#    /IN
#   f/NN
#   i/NN
#   r/VBP
#   s/NN
#   t/NN
#    /VBZ
#   a/DT
#   l/NN
#   l/NN
#   e/NN
#   g/NN
#   i/VBZ
#   a/DT
#   n/JJ
#   c/NN
#   e/NN
#   (Chunk  /NNP t/NN)
#   o/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP k/NN)
#   i/NN
#   n/VBP
#   g/NN
#   d/NN
#   o/IN
#   m/JJ
#   (Chunk  /NNP o/NN)
#   f/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP s/NN)
#   p/NN
#   i/NN
#   r/VBP
#   i/NN
#   t/NN
#   ,/,
#   (Chunk  /NNP)
#   w/VBP
#   h/NN
#   i/JJ
#   c/VBP
#   h/JJ
#    /NN
#   i/NN
#   s/VBP
#    /JJ
#   t/NN
#   h/NN
#   e/NN
#   (Chunk  /NNP t/NN)
#   r/NN
#   u/JJ
#   e/NN
#   (Chunk  /NNP s/NN)
#   o/NN
#   u/JJ
#   r/NN
#   c/NN
#   e/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP t/NN)
#   h/VBD
#   a/DT
#   t/NN
#    /NN
#   f/NN
#   r/NN
#   e/NN
#   e/NN
#   d/NN
#   o/IN
#   m/JJ
#   (Chunk  /NNP w/NN)
#   e/NN
#   (Chunk  /NNP)
#   v/VBZ
#   a/DT
#   l/NN
#   u/JJ
#   e/NN
#    /VBD
#   a/DT
#   b/NN
#   o/NN
#   v/NN
#   e/NN
#    /VBZ
#   a/DT
#   l/NN
#   l/NN
#   (Chunk  /NNP)
#   m/VBZ
#   a/DT
#   t/NN
#   e/NN
#   r/NN
#   i/VBZ
#   a/DT
#   l/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   i/JJ
#   n/VBP
#   g/JJ
#   s/NN
#   ./.
#
# /NN
#   (Chunk B/NNP u/NN)
#   t/NN
#    /VBZ
#   a/DT
#    /JJ
#   g/NN
#   o/NN
#   v/NN
#   e/NN
#   r/NN
#   n/JJ
#   m/NN
#   e/NN
#   n/JJ
#   t/NN
#   (Chunk  /NNP)
#   c/VBZ
#   a/DT
#   n/JJ
#    /NN
#   t/NN
#   r/NN
#   y/NN
#   ,/,
#    /VB
#   a/DT
#   s/JJ
#    /NN
#   o/NN
#   u/JJ
#   r/NN
#   s/NN
#   (Chunk  /NNP t/NN)
#   r/NN
#   i/NN
#   e/VBP
#   s/NN
#   ,/,
#   (Chunk  /NNP)
#   t/VBZ
#   o/JJ
#   (Chunk  /NNP s/NN)
#   e/NN
#   n/JJ
#   s/NN
#   e/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP d/NN)
#   e/NN
#   e/NN
#   p/NN
#   e/NN
#   s/NN
#   t/NN
#    /VBZ
#   a/DT
#   s/JJ
#   p/NN
#   i/NN
#   r/VBP
#   a/DT
#   t/NN
#   i/NN
#   o/VBP
#   n/JJ
#   s/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP p/NN)
#   e/NN
#   o/IN
#   p/NN
#   l/NN
#   e/NN
#   ,/,
#    /VB
#   a/DT
#   n/JJ
#   d/NN
#   (Chunk  /NNP t/NN)
#   o/NN
#   (Chunk  /NNP e/NN)
#   (Chunk x/NNP p/NN)
#   r/NN
#   e/NN
#   s/NN
#   s/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   m/NN
#    /NN
#   i/NN
#   n/VBP
#    /JJ
#   p/NN
#   o/IN
#   l/NN
#   i/NN
#   t/VBP
#   i/NN
#   c/VBP
#   a/DT
#   l/NN
#    /VBZ
#   a/DT
#   c/JJ
#   t/NN
#   i/NN
#   o/VBP
#   n/RB
#    /VBP
#   a/DT
#   t/NN
#    /NN
#   h/NN
#   o/JJ
#   m/NN
#   e/NN
#    /VBZ
#   a/DT
#   n/JJ
#   d/NN
#    /VBD
#   a/DT
#   b/NN
#   r/NN
#   o/IN
#   a/DT
#   d/NN
#   ./.
#    /JJ
#   (Chunk S/NNP o/NN)
#   (Chunk  /NNP l/NN)
#   o/NN
#   n/JJ
#   g/NN
#    /VBD
#   a/DT
#   s/NN
#    /VBZ
#   a/DT
#   c/JJ
#   t/NN
#   i/NN
#   o/VBP
#   n/RB
#    /VBP
#   a/DT
#   n/JJ
#   d/NN
#    /VBD
#   a/DT
#   s/JJ
#   p/NN
#   i/NN
#   r/VBP
#   a/DT
#   t/NN
#   i/NN
#   o/VBP
#   n/JJ
#   (Chunk  /NNP h/NN)
#   u/JJ
#   m/NN
#   b/NN
#   l/NN
#   y/NN
#    /VBZ
#   a/DT
#   n/JJ
#   d/NN
#   (Chunk  /NNP)
#   e/VBZ
#   a/DT
#   r/NN
#   n/JJ
#   e/NN
#   s/NN
#   t/NN
#   l/NN
#   y/NN
#   (Chunk  /NNP s/NN)
#   e/NN
#   e/NN
#   k/NN
#   (Chunk  /NNP)
#   f/VBZ
#   a/DT
#   v/NN
#   o/NN
#   r/NN
#    /NN
#   i/NN
#   n/VBP
#    /JJ
#   t/NN
#   h/NN
#   e/NN
#   (Chunk  /NNP s/NN)
#   i/NN
#   g/VBP
#   h/NN
#   t/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#    /VBZ
#   A/DT
#   l/JJ
#   m/NN
#   i/NN
#   g/VBP
#   h/NN
#   t/NN
#   y/NN
#   ,/,
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   r/NN
#   e/NN
#    /NN
#   i/NN
#   s/VBP
#    /JJ
#   n/JJ
#   o/NN
#   (Chunk  /NNP e/NN)
#   n/RB
#   d/JJ
#   (Chunk  /NNP t/NN)
#   o/NN
#   (Chunk  /VBZ A/NNP m/NN)
#   e/NN
#   r/NN
#   i/NN
#   c/VBP
#   a/DT
#   '/''
#   s/JJ
#   (Chunk  /NNP f/NN)
#   o/NN
#   r/NN
#   w/VBD
#   a/DT
#   r/NN
#   d/NN
#   (Chunk  /NNP r/NN)
#   o/VBD
#   a/DT
#   d/NN
#   ;/:
#    /CC
#   t/VB
#   h/NN
#   e/NN
#   r/NN
#   e/NN
#    /NN
#   i/NN
#   s/VBP
#    /JJ
#   n/JJ
#   o/NN
#   (Chunk  /NNP o/NN)
#   b/NN
#   s/NN
#   t/VBZ
#   a/DT
#   c/JJ
#   l/NN
#   e/NN
#   (Chunk  /NNP)
#   o/VBZ
#   n/JJ
#    /NN
#   i/NN
#   t/VBP
#    /JJ
#   s/NN
#   h/NN
#   e/NN
#   (Chunk  /NNP w/NN)
#   i/NN
#   l/VBP
#   l/NN
#   (Chunk  /NNP)
#   n/CC
#   o/JJ
#   t/NN
#   (Chunk  /NNP s/NN)
#   u/JJ
#   r/NN
#   m/NN
#   o/NN
#   u/JJ
#   n/JJ
#   t/NN
#    /NN
#   i/NN
#   n/VBP
#    /NN
#   h/NN
#   e/NN
#   r/NN
#   (Chunk  /NNP)
#   m/VBZ
#   a/DT
#   r/NN
#   c/NN
#   h/NN
#   (Chunk  /NNP t/NN)
#   o/NN
#   w/VBD
#   a/DT
#   r/NN
#   d/NN
#    /VBZ
#   a/DT
#    /JJ
#   l/NN
#   a/DT
#   s/JJ
#   t/NN
#   i/NN
#   n/VBP
#   g/NN
#   (Chunk  /NNP p/NN)
#   e/VBZ
#   a/DT
#   c/JJ
#   e/NN
#    /NN
#   i/NN
#   n/VBP
#    /PDT
#   a/DT
#    /NN
#   f/NN
#   r/NN
#   e/NN
#   e/NN
#    /VBZ
#   a/DT
#   n/JJ
#   d/NN
#   (Chunk  /NNP p/NN)
#   r/NN
#   o/NN
#   s/NN
#   p/NN
#   e/NN
#   r/NN
#   o/NN
#   u/JJ
#   s/NN
#   (Chunk  /NNP w/NN)
#   o/NN
#   r/NN
#   l/NN
#   d/NN
#   ./.
#
# /NN)
